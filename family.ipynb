# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/family.csv')

# %%
df.head(15)
# Out:
#     id                    Name    Birthday               Occupation  \
# 0    0  Briana Faith Feirstein   10/5/1996        Genetic Counselor
# 1    1     Marc Seth Bernstein   6/24/1998        Software engineer
# 2    2     Nina Rebecca Bigler   4/25/1994  Nonprofit Administrator
# 3    3      Megan Haley Fitter   10/2/1992            PhD Candidate
# 4    4   Eliana Lisa Bernstein   3/31/1995          Project Manager
# 5    5   Ariel Julian Abrahams   1/30/1988             Soundproofer
# 6    6      Rafi Noah Abrahams   8/23/1990                  Student
# 7    7  Juliana Rebecca Biller    6/3/1994         Paraprofessional
# 8    8          Jessica Fitter   5/19/1998                   Banker
# 9    9      Denise Emma Fitter  11/18/1994                Paralegal
# 10  10           Andrew Fitter   2/22/2001                  Student
# 11  11      Sean Pierce Fitter   9/24/2009                  Student
# 12  12   Myles Anderson Fitter   5/15/2012                  Student
# ...

# %%
df.loc[df['Favorite Holiday'] == 'Thanksgiving']
# Out:
#     id                    Name    Birthday               Occupation  \
# 0    0  Briana Faith Feirstein   10/5/1996        Genetic Counselor
# 1    1     Marc Seth Bernstein   6/24/1998        Software engineer
# 2    2     Nina Rebecca Bigler   4/25/1994  Nonprofit Administrator
# 3    3      Megan Haley Fitter   10/2/1992            PhD Candidate
# 4    4   Eliana Lisa Bernstein   3/31/1995          Project Manager
# 8    8          Jessica Fitter   5/19/1998                   Banker
# 9    9      Denise Emma Fitter  11/18/1994                Paralegal
# 10  10           Andrew Fitter   2/22/2001                  Student
# 11  11      Sean Pierce Fitter   9/24/2009                  Student
# 13  13        Raizel Bernstein   6/27/1993               unemployed
#
#    Favorite Holiday Favorite Season  \
# 0      Thanksgiving            Fall
# 1      Thanksgiving            Fall
# 2      Thanksgiving          Spring
# 3      Thanksgiving          Summer
# ...

# %%
Thanksgiving = len(df.loc[df['Favorite Holiday'] == 'Thanksgiving'])
Thanksgiving
# Out:
# 10

# %%
df['Favorite Holiday'].unique()
# Out:
# array([&#39;Thanksgiving&#39;, &#39;Yom Kippur&#39;, &#39;4.2&#39;, &#39;Passover&#39;, &#39;Chanukkah&#39;],
#       dtype=object)

# %%
Yom_Kippur = len(df.loc[df['Favorite Holiday'] == 'Yom Kippur'])
Yom_Kippur
# Out:
# 1

# %%
Weed = len(df.loc[df['Favorite Holiday'] == '4.2'])
Weed
# Out:
# 1

# %%
Passover = len(df.loc[df['Favorite Holiday'] == 'Passover'])
Passover
# Out:
# 1

# %%
Chanukkah = len(df.loc[df['Favorite Holiday'] == 'Chanukkah'])
Chanukkah
# Out:
# 1

# %%
fig, ax = plt.subplots()
y = [Thanksgiving, Yom_Kippur, Weed, Passover, Chanukkah]
x = ['Thanksgiving', 'Yom_Kippur', 'Weed', 'Passover', 'Hanukkah']
color = ['gold', 'black', 'lime', 'tan', 'cyan']
plt.bar(x, y, color = color)

ax.set_title('Favorite Holidays Amongst Cousins')
ax.set_xlabel('Holidays')
ax.set_ylabel('Number of Cousins')

plt.savefig('favholiday')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
df['Birthday'].head(14)
# Out:
# 0      10/5/1996
# 1      6/24/1998
# 2      4/25/1994
# 3      10/2/1992
# 4      3/31/1995
# 5      1/30/1988
# 6      8/23/1990
# 7       6/3/1994
# 8      5/19/1998
# 9     11/18/1994
# 10     2/22/2001
# 11     9/24/2009
# 12     5/15/2012
# 13     6/27/1993
# Name: Birthday, dtype: object

# %%
df['Birthday'].map(lambda x: x.replace('/',''))
# Out:
# 0      1051996
# 1      6241998
# 2      4251994
# 3      1021992
# 4      3311995
# 5      1301988
# 6      8231990
# 7       631994
# 8      5191998
# 9     11181994
# 10     2222001
# 11     9242009
# 12     5152012
# 13     6271993
# Name: Birthday, dtype: object

# %%
df['Year'] = df['Birthday'].map(lambda x: x.replace('/', '')[-4:])
df['Year']
# Out:
# 0     1996
# 1     1998
# 2     1994
# 3     1992
# 4     1995
# 5     1988
# 6     1990
# 7     1994
# 8     1998
# 9     1994
# 10    2001
# 11    2009
# 12    2012
# 13    1993
# Name: Year, dtype: object

# %%
current_year = 2020

# %%
for x in df['Year']:
    print(int(x))
# Out:
# 1996
# 1998
# 1994
# 1992
# 1995
# 1988
# 1990
# 1994
# 1998
# 1994
# 2001
# 2009
# 2012
# 1993

# %%
list(df['Year'])
# Out:
# [&#39;1996&#39;,
#  &#39;1998&#39;,
#  &#39;1994&#39;,
#  &#39;1992&#39;,
#  &#39;1995&#39;,
#  &#39;1988&#39;,
#  &#39;1990&#39;,
#  &#39;1994&#39;,
#  &#39;1998&#39;,
#  &#39;1994&#39;,
#  &#39;2001&#39;,
#  &#39;2009&#39;,
#  &#39;2012&#39;,
#  &#39;1993&#39;]

# %%
Year = list(df['Year'].map(lambda x : int(x)))
Year
# Out:
# [1996,
#  1998,
#  1994,
#  1992,
#  1995,
#  1988,
#  1990,
#  1994,
#  1998,
#  1994,
#  2001,
#  2009,
#  2012,
#  1993]

# %%
age = []
for x in Year: 
    ages = current_year - x
    age.append(ages)
print(age)
# Out:
# [24, 22, 26, 28, 25, 32, 30, 26, 22, 26, 19, 11, 8, 27]

# %%
# name_age_dict = {}
# for name in age:
#     name_age_dict[age] = df['Name']
# print(name_age_dict)

# %%
Fall = len(df.loc[df['Favorite Season'] == 'Fall'])

# %%
Winter = len(df.loc[df['Favorite Season'] == 'Winter'])

# %%
Spring = len(df.loc[df['Favorite Season'] == 'Spring'])

# %%
Summer = len(df.loc[df['Favorite Season'] == 'Summer'])

# %%
fig, ax = plt.subplots()
x = ['Winter', 'Spring', 'Summer', 'Fall']
y = [Winter, Spring, Summer, Fall]
color = ['silver', 'violet', 'deepskyblue', 'orange']
plt.bar(x, y, color = color)

ax.set_title('Favorite Season Amongst Cousins')
ax.set_xlabel('Seasons')
ax.set_ylabel('Number of Cousins')

plt.savefig('favseason')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
df_allergies = df.dropna(subset = ['Allergies'])
df_allergies.head()
# Out:
#     id                 Name   Birthday               Occupation  \
# 1    1  Marc Seth Bernstein  6/24/1998        Software engineer
# 2    2  Nina Rebecca Bigler  4/25/1994  Nonprofit Administrator
# 3    3   Megan Haley Fitter  10/2/1992            PhD Candidate
# 10  10        Andrew Fitter  2/22/2001                  Student
# 11  11   Sean Pierce Fitter  9/24/2009                  Student
#
#    Favorite Holiday Favorite Season                                Fun Fact  \
# 1      Thanksgiving            Fall                           Learning Bass
# 2      Thanksgiving          Spring  Learning to perfect the Israeli quiche
# 3      Thanksgiving          Summer             Does NOT like yellow cheese
# 10     Thanksgiving            Fall                                     NaN
# 11     Thanksgiving          Summer                       Black Belt in TKD
#
#                               Allergies       Favorite Sport   Resides  Year
# ...

# %%
df['Allergies'].unique()
# Out:
# array([nan, &#39;Penicillin&#39;, &#39;Peanuts and treenuts&#39;, &#39;diary&#39;,
#        &#39;Peanuts, cats, pollen, grass, trees&#39;,
#        &#39;peanuts, seasonal allergies&#39;], dtype=object)

# %%
df_allergies['Allergies'] = df_allergies['Allergies'].apply(lambda s: s.lower())
df_allergies[df_allergies['Allergies'].str.contains('peanuts')]
# Out:
#     id                Name   Birthday     Occupation Favorite Holiday  \
# 3    3  Megan Haley Fitter  10/2/1992  PhD Candidate     Thanksgiving
# 11  11  Sean Pierce Fitter  9/24/2009        Student     Thanksgiving
# 13  13    Raizel Bernstein  6/27/1993     unemployed     Thanksgiving
#
#    Favorite Season                     Fun Fact  \
# 3           Summer  Does NOT like yellow cheese
# 11          Summer            Black Belt in TKD
# 13            Fall               I hate running
#
#                               Allergies         Favorite Sport Resides  Year
# 3                  peanuts and treenuts          rock climbing    D.C.  1992
# 11  peanuts, cats, pollen, grass, trees               football      NJ  2009
# 13          peanuts, seasonal allergies  watching the bachelor      NJ  1993

# %%
df[(df['Allergies'].str.contains('peanuts')) | (df['Allergies'].str.contains('Peanuts'))]
# Out:
#     id                Name   Birthday     Occupation Favorite Holiday  \
# 3    3  Megan Haley Fitter  10/2/1992  PhD Candidate     Thanksgiving
# 11  11  Sean Pierce Fitter  9/24/2009        Student     Thanksgiving
# 13  13    Raizel Bernstein  6/27/1993     unemployed     Thanksgiving
#
#    Favorite Season                     Fun Fact  \
# 3           Summer  Does NOT like yellow cheese
# 11          Summer            Black Belt in TKD
# 13            Fall               I hate running
#
#                               Allergies         Favorite Sport Resides  Year
# 3                  Peanuts and treenuts          rock climbing    D.C.  1992
# 11  Peanuts, cats, pollen, grass, trees               football      NJ  2009
# 13          peanuts, seasonal allergies  watching the bachelor      NJ  1993

# %%
import datetime

# %%
now = pd.to_datetime('now')
df['Birthday'] = pd.to_datetime(df['Birthday'])
df
# Out:
#     id                    Name   Birthday               Occupation  \
# 0    0  Briana Faith Feirstein 1996-10-05        Genetic Counselor
# 1    1     Marc Seth Bernstein 1998-06-24        Software engineer
# 2    2     Nina Rebecca Bigler 1994-04-25  Nonprofit Administrator
# 3    3      Megan Haley Fitter 1992-10-02            PhD Candidate
# 4    4   Eliana Lisa Bernstein 1995-03-31          Project Manager
# 5    5   Ariel Julian Abrahams 1988-01-30             Soundproofer
# 6    6      Rafi Noah Abrahams 1990-08-23                  Student
# 7    7  Juliana Rebecca Biller 1994-06-03         Paraprofessional
# 8    8          Jessica Fitter 1998-05-19                   Banker
# 9    9      Denise Emma Fitter 1994-11-18                Paralegal
# 10  10           Andrew Fitter 2001-02-22                  Student
# 11  11      Sean Pierce Fitter 2009-09-24                  Student
# 12  12   Myles Anderson Fitter 2012-05-15                  Student
# ...

# %%
df.groupby(df['id'])['Name', 'Birthday'].head()
# Out:
#                       Name   Birthday
# 0   Briana Faith Feirstein 1996-10-05
# 1      Marc Seth Bernstein 1998-06-24
# 2      Nina Rebecca Bigler 1994-04-25
# 3       Megan Haley Fitter 1992-10-02
# 4    Eliana Lisa Bernstein 1995-03-31
# 5    Ariel Julian Abrahams 1988-01-30
# 6       Rafi Noah Abrahams 1990-08-23
# 7   Juliana Rebecca Biller 1994-06-03
# 8           Jessica Fitter 1998-05-19
# 9       Denise Emma Fitter 1994-11-18
# 10           Andrew Fitter 2001-02-22
# 11      Sean Pierce Fitter 2009-09-24
# 12   Myles Anderson Fitter 2012-05-15
# 13        Raizel Bernstein 1993-06-27

# %%
# for birthday in df['Birthday']:
#     age = now - birthday
#     print(age.astype('<m8[Y]'))
df['Age'] = (now - df['Birthday']).astype('<m8[Y]')

# %%
df.head(14)
# Out:
#     id                    Name   Birthday               Occupation  \
# 0    0  Briana Faith Feirstein 1996-10-05        Genetic Counselor
# 1    1     Marc Seth Bernstein 1998-06-24        Software engineer
# 2    2     Nina Rebecca Bigler 1994-04-25  Nonprofit Administrator
# 3    3      Megan Haley Fitter 1992-10-02            PhD Candidate
# 4    4   Eliana Lisa Bernstein 1995-03-31          Project Manager
# 5    5   Ariel Julian Abrahams 1988-01-30             Soundproofer
# 6    6      Rafi Noah Abrahams 1990-08-23                  Student
# 7    7  Juliana Rebecca Biller 1994-06-03         Paraprofessional
# 8    8          Jessica Fitter 1998-05-19                   Banker
# 9    9      Denise Emma Fitter 1994-11-18                Paralegal
# 10  10           Andrew Fitter 2001-02-22                  Student
# 11  11      Sean Pierce Fitter 2009-09-24                  Student
# 12  12   Myles Anderson Fitter 2012-05-15                  Student
# ...

# %%
plt.hist(df['Age'], bins = 18, align = 'mid', rwidth = .9)


# plt.set_title('Ages Amongst Cousins')
plt.xlabel('Age')
plt.ylabel('Number of Cousins')
plt.yticks([1,2,3])
plt.xticks(range(7,35))

plt.show()

plt.savefig('cosinhistogram')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 0 Axes&gt;

# %%
df['Age'].describe()
# Out:
# count    14.000000
# mean     23.142857
# std       6.700828
# min       8.000000
# 25%      22.000000
# 50%      25.000000
# 75%      26.750000
# max      32.000000
# Name: Age, dtype: float64

# %%
plt.boxplot(df['Age'], vert=False)

# fig, ax = plt.boxplot(df['Age'])
# plt.set_title('Age Amongst Cousins')
plt.xlabel('Age')

plt.savefig('cousinboxplot')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
