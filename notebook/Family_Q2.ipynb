# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', -1)

#git status, git add , git commit -m "", git push
# Out:
# <ipython-input-2-38d260f1d9f7>:9: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
Q2 = pd.read_csv('../data/Questionnaire_2.csv')

# %%
Q2 = Q2.rename(columns={'What is your name?':'Name', 'Next place on your travel bucket list':'Travel Destination',
                       'What is your most recent success? ':'Recent Success'})

# %%
# Q2.columns

# %%
Q2[['Name', 'Recent Success']].loc[Q2['Name'] == 'jay b']['Recent Success']
# Out:
# 5    One motion to help widow retain her benefits under little used concept of selective retroactivity statue
# Name: Recent Success, dtype: object

# %%
Q2[['Name', 'Recent Success']]
# Out:
#              Name  \
# 0   Bebe
# 1  Eliana
# 2  Marc Bernstein
# 3  Ariel
# 4  raf
# 5  jay b
# 6  Briana
# 7  Sean Fitter
# 8  Megan Fitter
#
#                                                                                              Recent Success
# 0  Driving to Maryland
# 1  Getting out of bed in the morning
# 2  NaN
# 3  Waking up rested
# 4  i woke up this morning
# 5  One motion to help widow retain her benefits under little used concept of selective retroactivity statue
# 6  Buying a house 🏠
# 7  2nd degree black belt
# 8  Finished a really cool rock climb!

# %%
Q2[['Name', 'What languages do you know (able to select multiple)?', "Make a sentence using the word 'iconoclast'.", "Make a sentence using the word 'bombastic'."]]
# Out:
#              Name     What languages do you know (able to select multiple)?  \
# 0   Bebe           English;Spanish;Resnik
# 1  Eliana          English
# 2  Marc Bernstein  English
# 3  Ariel           English;Hebrew
# 4  raf             English;Hebrew
# 5  jay b           English;Hebrew;Russian
# 6  Briana          English;Spanish;Resnik;ASL
# 7  Sean Fitter     English;Spanish
# 8  Megan Fitter    English;Why is American Sign Language not on here? #rude
#
#                                                                                         Make a sentence using the word 'iconoclast'.  \
# 0  Abuelita is an iconoclast
# 1  Raizel just learned the word iconoclast
# 2  NaN
# 3  A miracle worker, iconoclast, and low-key hydrophobe, young Jesus walked on water rather than getting in to swim with with boys.
# 4  as an iconoclast, i watch all of the MCU movies but i pretend i don't like them
# 5  my sentence was a kind of iconoclast!
# 6  I am an iconoclast of this foolishness about middle children being best
# 7  I don’t know what “iconoclast” means.
# 8  Megan was an iconoclast until the wordle word was "Ultra"
#
#                                                                                                                           Make a sentence using the word 'bombastic'.
# 0  Jay is bombastic.
# 1  that was totally bombastic
# 2  NaN
# 3  Although it seemed full of intention, Zoey’s high pitched squeal was but a bombastic outbursts; neither the judge nor the jury would take her comments seriously.
# 4  sean is a bombastic sports fan but when push comes to shove his brackets always fall apart. BOOM!
# 5  My bombastic entry excited everyone
# 6  It's important to tune out the elders when they get bombastic about their political views
# 7  Idk what bombastic means either. Maybe I should deselect English.
# 8  Wordle is bombastic

# %%
Q2[['Name', 'Which state has the best bagels?',
       "What's the secret ingredient in Ropa Vieja?",
       'Where do you get your coffee?',
       'How do you make your coffee at home (ex nespresso)?',
       'What kind of coffee do you drink (ex. Frap, ice coffee) and/or do you drink tea?',
       'If you got a dog or cat what would you name it?',
       'A chance to write whatever is on your mind (thanks for taking my survey!)']]
# Out:
#              Name Which state has the best bagels?  \
# 0   Bebe           Jersey
# 1  Eliana          Jersey
# 2  Marc Bernstein  Jersey
# 3  Ariel           Jersey
# 4  raf             Jersey
# 5  jay b           Jersey
# 6  Briana          NaN
# 7  Sean Fitter     Jersey
# 8  Megan Fitter    Jersey
#
#   What's the secret ingredient in Ropa Vieja?  \
# 0  Meat
# 1  Abuelita's love
# 2  Love
# 3  Cholent
# 4  old clothes
# 5  blood
# 6  Disdain for your grandchildren
# 7  Love lol
# 8  Capers
#
#                                  Where do you get your coffee?  \
# 0  Dunkin
# 1  don't drink it
# 2  I make it at home
# 3  I make it at home
# 4  I make it at home
# 5  I am better than everyone else because I don't drink coffee
# 6  I make it at home
# 7  Starbucks
# 8  Starbucks
#
#   How do you make your coffee at home (ex nespresso)?  \
# 0  Keurig
# 1  NaN
# 2  Mr. Coffee ice coffee maker
# 3  Drip
# 4  pourover
# 5  don't
# 6  Coffee maker
# 7  I don’t make coffee
# 8  French press
#
#           What kind of coffee do you drink (ex. Frap, ice coffee) and/or do you drink tea?  \
# 0  Hazelnut coffee
# 1  NaN
# 2  Ice coffee
# 3  Keep it simple- coffee w milk. In the afternoon I add maple syrup for Canadian flavor.
# 4  regular coffee w splash of soy milk
# 5  hot choco
# 6  Ice
# 7  Tea
# 8  Iced decaf coffee!
#
#             If you got a dog or cat what would you name it?  \
# 0  Never going to happen
# 1  Grey
# 2  Void
# 3  I have a perfect kiwi pup.
# 4  fuzzalina
# 5  freido
# 6  Hank
# 7  Tino
# 8  Pearson (after the statistician not the testing company)
#
#   A chance to write whatever is on your mind (thanks for taking my survey!)
# 0  Why?
# 1  NaN
# 2  NaN
# 3  Zoey: ‘gurgle’
# 4  love you raizel you're a cool cuz
# 5  Help me
# 6  NJ bagels are trash
# 7  First borns forever
# 8  Gotta blame it on my juice (baby)

# %%
orig = pd.read_csv('../data/Questionnaire.csv')

# %%
orig[['What is your name', 'What are your top 3 activities to do (hobbies, sports, crafts, etc)?', 'What is your favorite holiday?']]
# Out:
#           What is your name  \
# 0   Eliana
# 1   Miriam Bradman Abrahams
# 2   Bebe Bernstein
# 3   Briana
# 4   Sean Fitter
# 5   Bryan Fitter
# 6   Ana Fitter
# 7   Megan
# 8   Sheila Feirstein
# 9   Marc Bernstein
# 10  Jay
# 11  Rafi
# 12  Nina
# 13  Pola Bradman
# 14  Myles Fitter
# 15  Ariel
# 16  Jeffrey
# 17  Lori Krantz Fitter
# 18  Jessica Fitter
#
#    What are your top 3 activities to do (hobbies, sports, crafts, etc)?  \
# 0   Frisbee, eatting, sleeping
# 1   Reading, yoga, crocheting
# 2   read, walking, shopping
# 3   Cooking, watching hockey, bravo tv shows
# 4   Play video games, play football, watch YouTube/tv
# 5   Read, run, watch sports
# 6   Read, travel, play bridge
# 7   Obstacle racing, rock climbing, drinking tequila
# 8   Taking nature walks, painting,crafts
# 9   Video Games, Running, Watching TV
# 10  Hiking, astronomy, trumpet
# 11  board games and video games, hike and camp, listen to music
# 12  Dance, drawing, ping pong
# 13  Painting, writing poetry, reading books.
# 14  Playing video games, sports, spending time with family
# 15  Gaming, Nature Walks, Reading
# 16  NaN
# 17  walking, reading, listening to music
# 18  Reading, walking, traveling
#
#    What is your favorite holiday?
# 0   Thanksgiving
# 1   Thanksgiving
# 2   thanksgiving
# 3   Thanksgiving
# 4   Thanksgiving (duh)
# 5   Thanksgiving
# 6   Rosh Hashanah
# 7   Thanksgiving
# 8   Sabbath
# 9   Thanksgiving
# 10  My birthday
# 11  jewish christmas
# 12  Thanksgiving
# 13  Channukah
# 14  Chanukah
# 15  Thanksgiving
# 16  Thanksgiving
# 17  My birthday
# 18  Thanksgiving

# %%
orig[['What is your name', "What's your secret talent?", 'Most creative use of emojis',
       'If magic was real, what spell would you try to learn first?', 'Which relative do you think is most likely to win mario kart?', 'What is your best failure?',
     'Which is best?']]
# Out:
#           What is your name                  What's your secret talent?  \
# 0   Eliana                   Breaking a banana in half behind my back
# 1   Miriam Bradman Abrahams  Keeping close friends long term
# 2   Bebe Bernstein           cooking
# 3   Briana                   Xray vision
# 4   Sean Fitter              Tae kwon do
# 5   Bryan Fitter             Observing
# 6   Ana Fitter               Talking to people
# 7   Megan                    I can do a headstand
# 8   Sheila Feirstein         It’s a secret
# 9   Marc Bernstein           Talentless
# 10  Jay                      Coming up with original theories and ideas
# 11  Rafi                     hmm idk im waiting to find out
# 12  Nina                     NaN
# 13  Pola Bradman             Knowing people quickly.
# 14  Myles Fitter             Making eggs
# 15  Ariel                    I don't know if I have one
# 16  Jeffrey                  NaN
# 17  Lori Krantz Fitter       Writing with both ands at  the same time.
# 18  Jessica Fitter           Makeup
#
#                                              Most creative use of emojis  \
# 0   Welcome to good burger line in emojis
# 1   🍹🍱🍕🍳🧀🥑🍿🍩🥠🍪🍫🍦🍨☕️🍮
# 2   whatever
# 3   I just took a 🧬 test turns out i'm 💯 that 🅱️ℹ✝️☪️♊
# 4   Birthdays
# 5   Not applicable
# 6   Action emojis
# 7   Trying to fingerspell in American Sign Language with the hand emojis
# 8   TBD
# 9   ༼ つ ◕_◕ ༽つ
# 10  Poop
# 11  pre-emoji shrug: ¯\_(ツ)_/¯
# 12  NaN
# 13  I do not use emojis.
# 14  Facial expressions
# 15  What do you mean
# 16  NaN
# 17  My Google Classroom
# 18  ➖📚➖
#
#    If magic was real, what spell would you try to learn first?  \
# 0   Teleportation spell
# 1   Isn’t it real? I’m a bit of a witch;)! Healing spell
# 2   invisibility
# 3   One to clean up my place
# 4   How to shut up a middle child
# 5   Invisibility
# 6   Shut up stupid conversations
# 7   Accio completed dissertation!
# 8   Make people disappear and reappear
# 9   Teleportation
# 10  Control over time
# 11  talk to bugs
# 12  NaN
# 13  How to make disappear scams.
# 14  How to fly
# 15  How to fly
# 16  NaN
# 17  Quiet spell
# 18  Invisibility
#
#    Which relative do you think is most likely to win mario kart?  \
# 0   Eliana
# 1   Rafi
# 2   Marc
# 3   Not marc
# 4   Marc
# 5   Marc
# 6   Anita
# 7   Marc
# 8   Briana
# 9   Marc
# 10  Marc
# 11  marc :( unless nick is playing
# 12  Sean
# 13  I don´t know.
# 14  Marc
# 15  Lori
# 16  Mark
# 17  Marc
# 18  Raizel
#
#                                                                                                                                 What is your best failure?  \
# 0   One time raizel and Marc both stole sodas out of my hand so when I pulled the last one it had the winning bottle cap
# 1   Wtf does that mean?! Failure is no fun
# 2   NJ License project sending someone to jail
# 3   Getting rejected by my top 5 grad programs
# 4   This years March madness bracket
# 5   My MasterCard conversion project at Citi. Did not accomplish what it needed too, but accomplished sooooo much more that what people thought it would.
# 6   Not following my instincts
# 7   I work too hard and am too successful and good looking
# 8   Giving in to filling out this form
# 9   Thinking I am athletic
# 10  The bar exam
# 11  quitting my job
# 12  NaN
# 13  To understand some of the questions.
# 14  Trying to create a musical group
# 15  Too many
# 16  NaN
# 17  My first teaching job.
# 18  I’ve never found the afikomen
#
#                                    Which is best?
# 0   Middle children
# 1   Oldest children (duh)
# 2   Oldest children (duh)
# 3   Youngest children
# 4   Oldest children (duh)
# 5   Youngest children
# 6   Oldest children (duh)
# 7   Oldest children (duh)
# 8   Youngest children
# 9   Youngest children
# 10  Jessica and Jay (is anyone else a 3rd child?)
# 11  Middle children
# 12  Youngest children
# 13  Youngest children
# 14  Youngest children
# 15  Oldest children (duh)
# 16  Middle children
# 17  Youngest children
# 18  Jessica and Jay (is anyone else a 3rd child?)

# %%
orig[orig["Which relative do you think is most likely to win mario kart?"].str.contains('nick')]
# Out:
#                     Timestamp What is your name Blood Type  \
# 11  2021/04/02 7:05:09 PM AST  Rafi              O
#
#    What is your birthday  \
# 11  8/23/1990
#
#    Do you have pets? How many? What kind (cat, dog, etc), provide names  \
# 11  Fuzz (cat, age 8)
#
#    If you can have any super power what power would you have?  \
# 11  talk to bugs
#
#    What are your top 3 activities to do (hobbies, sports, crafts, etc)?  \
# 11  board games and video games, hike and camp, listen to music
#
#    What is your favorite holiday? Introvert or Extrovert Podcast or Music  \
# 11  jewish christmas               Introvert              Music
#
#    Next place on your travel bucket list beach or mountains  \
# 11  japan                                 mountains
#
#    what's your favorite: breakfast, lunch, dinner  \
# 11  dinner
#
#    apple products or not apple products coffee or tea  \
# 11  apple                                coffee
#
#    Would you like to run a leg of a marathon on October 17, 2021 in Jersey?   \
# 11  lol maybe an extremely short one
#
#    If you could have anyone at your birthday, who would it be?  \
# 11  raizel
#
#         What's your secret talent?  Most creative use of emojis  \
# 11  hmm idk im waiting to find out  pre-emoji shrug: ¯\_(ツ)_/¯
#
#    If magic was real, what spell would you try to learn first?  \
# 11  talk to bugs
#
#    Which value(s) is most important to you? [It should allow you to choose more than one but if not oh well this is my first time using this thing]  \
# 11  Joy;Justice;Learning;Love;Nature
#
#    Who do you think will win improv allstar in 2021?  \
# 11  ugh plz not alex anyone else is fine
#
#    Relative that is most likely to win a sports bracket?  \
# 11  bri
#
#    Which relative is most likely to find the afikoman?  \
# 11  bri
#
#    If Rafi and Jeffrey were playing a board game who would win?  \
# 11  Jeffrey
#
#    Besides Anita Pola and Juan, which relative knows the most Spanish?  \
# 11  aida lol
#
#    Which relative do you think is most likely to win mario kart?  \
# 11  marc :( unless nick is playing
#
#    Attachment Style   Which is best? Which describes you best?  \
# 11  Secure           Middle children  Liberal
#
#    Mask or no mask  Raizel, HOW MANY MORE QUESTIONS ARE THERE?  \
# 11  mask            I expect an open bar at Sean's Bar mitzvah
#
#    What is your best failure?  \
# 11  quitting my job
#
#                Top 3 songs you want to hear at Club Turkey?
# 11  drivers license, beez in the trap, baby (justin bieber)

# %%
orig["Which relative do you think is most likely to win mario kart?"].str.contains('nick', case=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# Name: Which relative do you think is most likely to win mario kart?, dtype: bool

# %%
orig['test_lamb'] = orig.apply(lambda x: 'empty' if pd.isnull(x['What is your best failure?']) else x['What is your best failure?'], axis=1)

# %%
orig["Which relative do you think is most likely to win mario kart?"] = orig["Which relative do you think is most likely to win mario kart?"].apply(lambda x: x.replace('marc :( unless nick is playing', 'Marc'))

# %%
# orig.head()

# %%
# orig["Which relative do you think is most likely to win mario kart?"] = orig[orig["Which relative do you think is most likely to win mario kart?"].str.contains('nick')].replace({True:'Marc'})

# %%
# orig.apply(lambda x: 'Marc' if (x["Which relative do you think is most likely to win mario kart?"].str.contains('nick')) else x["Which relative do you think is most likely to win mario kart?"], axis=1)

# %%
# orig.dtypes

# %%
# orig = orig[orig["Which relative do you think is most likely to win mario kart?"].str.contains('nick')].str.replace("unless nick is playing", 'Marc')
# orig.head()

# %%
orig["Which relative do you think is most likely to win mario kart?"].value_counts().plot.bar(figsize=(15,7), 
                                                                        color=["midnightblue", "fuchsia", "darkmagenta"])
plt.xticks(rotation = 90)
plt.title(label = "Who'd ya think would win mario kart - MarC or MarK", fontsize = 22)
plt.xlabel('Players', fontdict={'fontsize': 15})
plt.ylabel('Number of Votes', fontsize=15)

# plt.savefig('../graphs/MarioKart.png')
# Out:
# Text(0, 0.5, 'Number of Votes')

# %%
orig.head(2)
# Out:
#                    Timestamp        What is your name Blood Type  \
# 0  2021/04/02 2:15:22 PM AST  Eliana                   O
# 1  2021/04/02 2:31:29 PM AST  Miriam Bradman Abrahams  O
#
#   What is your birthday  \
# 0  3/31/1995
# 1  1/27/1961
#
#   Do you have pets? How many? What kind (cat, dog, etc), provide names  \
# 0  No
# 1  Nope
#
#   If you can have any super power what power would you have?  \
# 0  Teleportation
# 1  Flying
#
#   What are your top 3 activities to do (hobbies, sports, crafts, etc)?  \
# 0  Frisbee, eatting, sleeping
# 1  Reading, yoga, crocheting
#
#   What is your favorite holiday? Introvert or Extrovert Podcast or Music  \
# 0  Thanksgiving                   Introvert              Music
# 1  Thanksgiving                   Extrovert              Music
#
#   Next place on your travel bucket list beach or mountains  \
# 0  Bora bora                             beach
# 1  Portugal                              beach
#
#   what's your favorite: breakfast, lunch, dinner  \
# 0  dinner
# 1  lunch
#
#   apple products or not apple products  coffee or tea  \
# 0  apple                                tea
# 1  apple                                Hot chocolate
#
#   Would you like to run a leg of a marathon on October 17, 2021 in Jersey?   \
# 0  Probs not
# 1  Nope
#
#   If you could have anyone at your birthday, who would it be?  \
# 0  Britney bitch
# 1  Israeli Singer Idan Raichel
#
#                  What's your secret talent?  \
# 0  Breaking a banana in half behind my back
# 1  Keeping close friends long term
#
#              Most creative use of emojis  \
# 0  Welcome to good burger line in emojis
# 1  🍹🍱🍕🍳🧀🥑🍿🍩🥠🍪🍫🍦🍨☕️🍮
#
#   If magic was real, what spell would you try to learn first?  \
# 0  Teleportation spell
# 1  Isn’t it real? I’m a bit of a witch;)! Healing spell
#
#                                                                                                                                               Which value(s) is most important to you? [It should allow you to choose more than one but if not oh well this is my first time using this thing]  \
# 0  Adventure;Belonging;Community;Compassion;Cooperation;Creativity;Curiosity;Equality;Fun;Home;Honesty;Inclusion;Independence;Loyalty;Nature;Patience;Sportsmanship;Teamwork;Tradition;Travel;Trust
# 1  Adaptability;Authenticity;Caring;Community;Compassion;Connection;Contentment;Creativity;Curiosity;Environment;Ethics;Fairness;Family;Friendship;Fun;Health;Honesty;Humor;Integrity;Joy;Knowledge;Learning;Leisure;Love;Nature;Peace;Travel;Understanding;Well-being;Wholeheartedness;Wisdom
#
#   Who do you think will win improv allstar in 2021?  \
# 0  Marc
# 1  No idea
#
#   Relative that is most likely to win a sports bracket?  \
# 0  Bryan
# 1  Bryan
#
#   Which relative is most likely to find the afikoman?  \
# 0  Myles
# 1  Briana
#
#   If Rafi and Jeffrey were playing a board game who would win?  \
# 0  Jeffrey
# 1  Jeffrey
#
#   Besides Anita Pola and Juan, which relative knows the most Spanish?  \
# 0  Beatrice
# 1  Yo hablo español mejor que los otros;) jajaja
#
#   Which relative do you think is most likely to win mario kart?  \
# 0  Eliana
# 1  Rafi
#
#   Attachment Style         Which is best? Which describes you best?  \
# 0  Anxious          Middle children        Liberal
# 1  Anxious          Oldest children (duh)  Liberal
#
#   Mask or no mask  Raizel, HOW MANY MORE QUESTIONS ARE THERE?  \
# 0  mask            I expect an open bar at Sean's Bar mitzvah
# 1  mask            I expect an open bar at Sean's Bar mitzvah
#
#                                                                                              What is your best failure?  \
# 0  One time raizel and Marc both stole sodas out of my hand so when I pulled the last one it had the winning bottle cap
# 1  Wtf does that mean?! Failure is no fun
#
#                                       Top 3 songs you want to hear at Club Turkey?
# 0  1. Anything Shakira 2. Petron tequila I’m drunk on margarita 3. Anything Kesha
# 1  Anything by Justin Timberlake

# %%
orig["Do you have pets? How many? What kind (cat, dog, etc), provide names"]  = np.where(((orig["Do you have pets? How many? What kind (cat, dog, etc), provide names"] == 'Nope') | (orig["Do you have pets? How many? What kind (cat, dog, etc), provide names"] == 'No')), 
         'I do not have pets', orig["Do you have pets? How many? What kind (cat, dog, etc), provide names"])

# %%
orig["Do you have pets? How many? What kind (cat, dog, etc), provide names"]
# Out:
# 0     I do not have pets
# 1     Nope
# 2     no
# 3     I do not have pets
# 4     I do not have pets
# 5     No pets
# 6     No pets
# 7     1 mini poodle named Lexie (nicknames: fluffernugget, floofykins, the little floofer, little, lexigram)
# 8     One dog
# 9     NaN
# 10    I do not have pets
# 11    Fuzz (cat, age 8)
# 12    Plant, 1, menashe
# 13    NO
# 14    I do not have pets
# 15    1 Kiwi Dog
# 16    1 dog Lexie
# 17    I do not have pets
# 18    Dog, little girl lexie
# Name: Do you have pets? How many? What kind (cat, dog, etc), provide names, dtype: object
