# %% [markdown]
# https://www.census.gov/geographies/mapping-files/time-series/geo/cartographic-boundary.html

# %% [markdown]
# https://jcutrer.com/python/learn-geopandas-plotting-usmaps

# %%
import pandas as pd
import geopandas
import math
import matplotlib.pyplot as plt

# %%
#make sure to have all the files in the states_2020 folder otherwise shp won't run
#extract to unzip
states = geopandas.read_file('../Data_science/states_2020/cb_2020_us_state_5m.shp')
states.head()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../Data_science/states_2020/cb_2020_us_state_5m.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-6-436dc48b4a1b> in <module>
#       1 #make sure to have all the files in the states_2020 folder otherwise shp won't run
#       2 #extract to unzip
# ----> 3 states = geopandas.read_file('../Data_science/states_2020/cb_2020_us_state_5m.shp')
#       4 states.head()
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, bbox, **kwargs)
#      74
#      75     with fiona_env():
# ...

# %%
states.shape
# Out:
# (56, 10)

# %%
# pip install -i https://pypi.anaconda.org/mkhines/simple descartes
from descartes.patch import PolygonPatch

# %%
states.plot()
# Out:
# <AxesSubplot:>

# %%
states_50 = states[~states['STUSPS'].isin(['GU', 'AS', 'AK', 'PR', 'VI', 'MP'])]
states_50.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS           NAME LSAD  \
# 0      55  01779806  0400000US55    55     WI      Wisconsin   00
# 1      54  01779805  0400000US54    54     WV  West Virginia   00
# 2      16  01779783  0400000US16    16     ID          Idaho   00
# 3      27  00662849  0400000US27    27     MN      Minnesota   00
# 4      19  01779785  0400000US19    19     IA           Iowa   00
#
#           ALAND       AWATER  \
# 0  140292246684  29343721650
# 1   62266296765    489206049
# 2  214049923496   2391577745
# 3  206232157570  18949864226
# 4  144659688848   1085996889
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.95620 45.35201, -86.95339 ...
# 1  POLYGON ((-82.64300 38.16956, -82.63905 38.171...
# 2  POLYGON ((-117.24267 44.39655, -117.23484 44.3...
# 3  POLYGON ((-97.23921 48.96868, -97.23802 48.975...
# 4  POLYGON ((-96.63970 42.73707, -96.63589 42.741...

# %%
states_50.shape
# Out:
# (50, 10)

# %%
states_50.plot()
# Out:
# <AxesSubplot:>

# %%
states_50.boundary.plot(figsize=(40,15))
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(29,12))
states_50.apply(lambda x: ax.annotate(s=x.STUSPS, xy=x.geometry.centroid.coords[0], ha='center', fontsize=11, color = 'black'), axis=1);
states_50.boundary.plot(ax=ax, color='black', linewidth = .2)
states_50.plot(ax=ax, cmap = 'Blues')

plt.savefig('US_state_map')
# Out:
# <ipython-input-11-e9a6bd41da0d>:2: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   states_50.apply(lambda x: ax.annotate(s=x.STUSPS, xy=x.geometry.centroid.coords[0], ha='center', fontsize=11, color = 'black'), axis=1);

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))

# %% [markdown]
# https://geopandas.org/en/stable/docs/user_guide/mapping.html

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,7))

world.plot(column='pop_est', ax=ax, legend=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fd8f6ca72736> in <module>
#       1 fig, ax = plt.subplots(1, 1, figsize=(15,7))
#       2
# ----> 3 world.plot(column='pop_est', ax=ax, legend=True)
#
# NameError: name 'world' is not defined
