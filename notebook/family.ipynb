# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/family.csv')

# %%
df.head(15)
# Out:
#     id                    Name    Birthday               Occupation  \
# 0    0  Briana Faith Feirstein   10/5/1996        Genetic Counselor
# 1    1     Marc Seth Bernstein   6/24/1998        Software engineer
# 2    2     Nina Rebecca Bigler   4/25/1994  Nonprofit Administrator
# 3    3      Megan Haley Fitter   10/2/1992            PhD Candidate
# 4    4   Eliana Lisa Bernstein   3/31/1995          Project Manager
# 5    5   Ariel Julian Abrahams   1/30/1988             Soundproofer
# 6    6      Rafi Noah Abrahams   8/23/1990                  Student
# 7    7  Juliana Rebecca Biller    6/3/1994         Paraprofessional
# 8    8          Jessica Fitter   5/19/1998                   Banker
# 9    9      Denise Emma Fitter  11/18/1994                Paralegal
# 10  10           Andrew Fitter   2/22/2001                  Student
# 11  11      Sean Pierce Fitter   9/24/2009                  Student
# 12  12   Myles Anderson Fitter   5/15/2012                  Student
# ...

# %%
df.loc[df['Favorite Holiday'] == 'Thanksgiving']
# Out:
#     id                    Name    Birthday               Occupation  \
# 0    0  Briana Faith Feirstein   10/5/1996        Genetic Counselor
# 1    1     Marc Seth Bernstein   6/24/1998        Software engineer
# 2    2     Nina Rebecca Bigler   4/25/1994  Nonprofit Administrator
# 3    3      Megan Haley Fitter   10/2/1992            PhD Candidate
# 4    4   Eliana Lisa Bernstein   3/31/1995          Project Manager
# 8    8          Jessica Fitter   5/19/1998                   Banker
# 9    9      Denise Emma Fitter  11/18/1994                Paralegal
# 10  10           Andrew Fitter   2/22/2001                  Student
# 11  11      Sean Pierce Fitter   9/24/2009                  Student
# 13  13        Raizel Bernstein   6/27/1993               unemployed
#
#    Favorite Holiday Favorite Season  \
# 0      Thanksgiving            Fall
# 1      Thanksgiving            Fall
# 2      Thanksgiving          Spring
# 3      Thanksgiving          Summer
# ...

# %%
Thanksgiving = len(df.loc[df['Favorite Holiday'] == 'Thanksgiving'])
Thanksgiving
# Out:
# 10

# %%
df['Favorite Holiday'].unique()
# Out:
# array(['Thanksgiving', 'Yom Kippur', '4.2', 'Passover', 'Chanukkah'],
#       dtype=object)

# %%
df['Favorite Holiday'].value_counts().values
# Out:
# array([10,  1,  1,  1,  1], dtype=int64)

# %%
df['Favorite Holiday'].unique()
# Out:
# array(['Thanksgiving', 'Yom Kippur', '4.2', 'Passover', 'Chanukkah'],
#       dtype=object)

# %%
Yom_Kippur = len(df.loc[df['Favorite Holiday'] == 'Yom Kippur'])
Yom_Kippur
# Out:
# 1

# %%
Weed = len(df.loc[df['Favorite Holiday'] == '4.2'])
Weed
# Out:
# 1

# %%
Passover = len(df.loc[df['Favorite Holiday'] == 'Passover'])
Passover
# Out:
# 1

# %%
Chanukkah = len(df.loc[df['Favorite Holiday'] == 'Chanukkah'])
Chanukkah
# Out:
# 1

# %%
fig, ax = plt.subplots()
y = [Thanksgiving, Yom_Kippur, Weed, Passover, Chanukkah]
x = ['Thanksgiving', 'Yom_Kippur', 'Weed', 'Passover', 'Hanukkah']
color = ['gold', 'black', 'lime', 'tan', 'cyan']
plt.bar(x, y, color = color)

ax.set_title('Favorite Holidays Amongst Cousins')
ax.set_xlabel('Holidays')
ax.set_ylabel('Number of Cousins')

plt.savefig('favholiday')

# %%
fig, ax = plt.subplots(figsize=(9,5))
df['Favorite Holiday'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Favorite Holiday'>

# %%
fig, ax = plt.subplots(figsize=(15,7))
x = df['Favorite Holiday'].unique()
y = df['Favorite Holiday'].value_counts().values
color = ['goldenrod', 'black', 'mediumseagreen', 'sandybrown', 'mediumblue']
plt.bar(x, y, color = color)

ax.set_title('Favorite Holidays Amongst Cousins', fontsize=22)
ax.set_xlabel('Holidays', fontsize=16)
ax.set_ylabel('Number of Cousins', fontsize=16)
plt.xticks(fontsize=12)

# plt.savefig('graphs/favholiday.png')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df['Favorite Holiday'].unique()
# Out:
# array(['Thanksgiving', 'Yom Kippur', '4.2', 'Passover', 'Chanukkah'],
#       dtype=object)

# %%
for holiday in df['Favorite Holiday'].unique():
    print(holiday)
# Out:
# Thanksgiving
# Yom Kippur
# 4.2
# Passover
# Chanukkah

# %%
holidays = {}
for holiday in df['Favorite Holiday'].unique():
    print(holiday, len(df.loc[df['Favorite Holiday'] == holiday]))
    holidays[holiday] = len(df.loc[df['Favorite Holiday'] == holiday])
# Out:
# Thanksgiving 10
# Yom Kippur 1
# 4.2 1
# Passover 1
# Chanukkah 1

# %%
holidays
# Out:
# {'Thanksgiving': 10, 'Yom Kippur': 1, '4.2': 1, 'Passover': 1, 'Chanukkah': 1}

# %%
df['Birthday'].head(14)
# Out:
# 0      10/5/1996
# 1      6/24/1998
# 2      4/25/1994
# 3      10/2/1992
# 4      3/31/1995
# 5      1/30/1988
# 6      8/23/1990
# 7       6/3/1994
# 8      5/19/1998
# 9     11/18/1994
# 10     2/22/2001
# 11     9/24/2009
# 12     5/15/2012
# 13     6/27/1993
# Name: Birthday, dtype: object

# %%
df['Birthday'].dtypes
df['Birthday'].str.replace('/','')
# Out:
# 0      1051996
# 1      6241998
# 2      4251994
# 3      1021992
# 4      3311995
# 5      1301988
# 6      8231990
# 7       631994
# 8      5191998
# 9     11181994
# 10     2222001
# 11     9242009
# 12     5152012
# 13     6271993
# Name: Birthday, dtype: object

# %%
df['Birthday'].map(lambda x: x.replace('/',''))
df['Birthday'].dtypes
# Out:
# dtype('O')

# %%
df['Year'] = df['Birthday'].map(lambda x: x.replace('/', '')[-4:])
df['Year']
# Out:
# 0     1996
# 1     1998
# 2     1994
# 3     1992
# 4     1995
# 5     1988
# 6     1990
# 7     1994
# 8     1998
# 9     1994
# 10    2001
# 11    2009
# 12    2012
# 13    1993
# Name: Year, dtype: object

# %%
current_year = 2022

# %%
for x in df['Year']:
    print(int(x))
# Out:
# 1996
# 1998
# 1994
# 1992
# 1995
# 1988
# 1990
# 1994
# 1998
# 1994
# 2001
# 2009
# 2012
# 1993

# %%
list(df['Year'])
# Out:
# ['1996',
#  '1998',
#  '1994',
#  '1992',
#  '1995',
#  '1988',
#  '1990',
#  '1994',
#  '1998',
#  '1994',
#  '2001',
#  '2009',
#  '2012',
#  '1993']

# %%
Year = list(df['Year'].map(lambda x : int(x)))
Year
# Out:
# [1996,
#  1998,
#  1994,
#  1992,
#  1995,
#  1988,
#  1990,
#  1994,
#  1998,
#  1994,
#  2001,
#  2009,
#  2012,
#  1993]

# %%
age = []
for x in Year: 
    ages = current_year - x
    age.append(ages)
print(age)
# Out:
# [26, 24, 28, 30, 27, 34, 32, 28, 24, 28, 21, 13, 10, 29]

# %%
# name_age_dict = {}
# for name in age:
#     name_age_dict[age] = df['Name']
# print(name_age_dict)

# %%
Fall = len(df.loc[df['Favorite Season'] == 'Fall'])

# %%
Winter = len(df.loc[df['Favorite Season'] == 'Winter'])

# %%
Spring = len(df.loc[df['Favorite Season'] == 'Spring'])

# %%
Summer = len(df.loc[df['Favorite Season'] == 'Summer'])

# %%
fig, ax = plt.subplots()
x = ['Winter', 'Spring', 'Summer', 'Fall']
y = [Winter, Spring, Summer, Fall]
color = ['silver', 'violet', 'deepskyblue', 'orange']
plt.bar(x, y, color = color)

ax.set_title('Favorite Season Amongst Cousins')
ax.set_xlabel('Seasons')
ax.set_ylabel('Number of Cousins')

plt.savefig('favseason')

# %%
df_allergies = df.dropna(subset = ['Allergies'])
df_allergies.head()
# Out:
#     id                 Name   Birthday               Occupation  \
# 1    1  Marc Seth Bernstein  6/24/1998        Software engineer
# 2    2  Nina Rebecca Bigler  4/25/1994  Nonprofit Administrator
# 3    3   Megan Haley Fitter  10/2/1992            PhD Candidate
# 10  10        Andrew Fitter  2/22/2001                  Student
# 11  11   Sean Pierce Fitter  9/24/2009                  Student
#
#    Favorite Holiday Favorite Season                                Fun Fact  \
# 1      Thanksgiving            Fall                           Learning Bass
# 2      Thanksgiving          Spring  Learning to perfect the Israeli quiche
# 3      Thanksgiving          Summer             Does NOT like yellow cheese
# 10     Thanksgiving            Fall                                     NaN
# 11     Thanksgiving          Summer                       Black Belt in TKD
#
#                               Allergies       Favorite Sport   Resides  Year
# ...

# %%
df['Allergies'].unique()
# Out:
# array([nan, 'Penicillin', 'Peanuts and treenuts', 'diary',
#        'Peanuts, cats, pollen, grass, trees',
#        'peanuts, seasonal allergies'], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(9,7))
df['Allergies'].value_counts().plot(kind='pie', colors = ['blue', 'green', 'chartreuse', 'purple', 'grey'])
# Out:
# <AxesSubplot:ylabel='Allergies'>

# %%
df[df['Allergies'].str.contains('peanuts', case=False) == True]
# Out:
#     id                Name   Birthday     Occupation Favorite Holiday  \
# 3    3  Megan Haley Fitter  10/2/1992  PhD Candidate     Thanksgiving
# 11  11  Sean Pierce Fitter  9/24/2009        Student     Thanksgiving
# 13  13    Raizel Bernstein  6/27/1993     unemployed     Thanksgiving
#
#    Favorite Season                     Fun Fact  \
# 3           Summer  Does NOT like yellow cheese
# 11          Summer            Black Belt in TKD
# 13            Fall               I hate running
#
#                               Allergies         Favorite Sport Resides
# 3                  Peanuts and treenuts          rock climbing    D.C.
# 11  Peanuts, cats, pollen, grass, trees               football      NJ
# 13          peanuts, seasonal allergies  watching the bachelor      NJ

# %%
#replace peanuts in the allergy specific column
df.loc[df['Allergies'].str.contains('peanuts', case=False) == True, 'Allergies'] = 'peanuts'
df['Allergies'].value_counts().plot(kind='pie', colors = ['brown', 'blue', 'red'])
# Out:
# <AxesSubplot:ylabel='Allergies'>

# %%
df.loc[df['Fun Fact'].str.contains('I hate running', case=False) == True, 'Favorite Season'] = 'F A L L'

# %%
df.tail()
# Out:
#     id                   Name    Birthday    Occupation Favorite Holiday  \
# 9    9     Denise Emma Fitter  11/18/1994     Paralegal     Thanksgiving
# 10  10          Andrew Fitter   2/22/2001       Student     Thanksgiving
# 11  11     Sean Pierce Fitter   9/24/2009       Student     Thanksgiving
# 12  12  Myles Anderson Fitter   5/15/2012       Student        Chanukkah
# 13  13       Raizel Bernstein   6/27/1993  data science     Thanksgiving
#
#    Favorite Season                                           Fun Fact  \
# 9             Fall  I have the best cats in the world! Oh and I ju...
# 10            Fall                                                NaN
# 11          Summer                                  Black Belt in TKD
# 12            Fall                Can climb to the roof of a play set
# 13         F A L L                                     I hate running
#
#                               Allergies         Favorite Sport   Resides
# ...

# %%
#didn't work
df['Allergies'] = df['Allergies'].apply(lambda x: 'peanut' if x == 'peanut' in x else x)
df['Allergies']
# Out:
# 0                                     NaN
# 1                              Penicillin
# 2                              Penicillin
# 3                    Peanuts and treenuts
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                  diary
# 11    Peanuts, cats, pollen, grass, trees
# 12                                    NaN
# 13            peanuts, seasonal allergies
# Name: Allergies, dtype: object

# %%
df_allergies['Allergies'] = df_allergies['Allergies'].apply(lambda s: s.lower())
df_allergies[df_allergies['Allergies'].str.contains('peanuts')]
# Out:
#     id                Name   Birthday     Occupation Favorite Holiday  \
# 3    3  Megan Haley Fitter  10/2/1992  PhD Candidate     Thanksgiving
# 11  11  Sean Pierce Fitter  9/24/2009        Student     Thanksgiving
# 13  13    Raizel Bernstein  6/27/1993     unemployed     Thanksgiving
#
#    Favorite Season                     Fun Fact  \
# 3           Summer  Does NOT like yellow cheese
# 11          Summer            Black Belt in TKD
# 13            Fall               I hate running
#
#                               Allergies         Favorite Sport Resides  Year
# 3                  peanuts and treenuts          rock climbing    D.C.  1992
# 11  peanuts, cats, pollen, grass, trees               football      NJ  2009
# 13          peanuts, seasonal allergies  watching the bachelor      NJ  1993

# %%
df[(df['Allergies'].str.contains('peanuts')) | (df['Allergies'].str.contains('Peanuts'))]
# Out:
#     id                Name   Birthday     Occupation Favorite Holiday  \
# 3    3  Megan Haley Fitter  10/2/1992  PhD Candidate     Thanksgiving
# 11  11  Sean Pierce Fitter  9/24/2009        Student     Thanksgiving
# 13  13    Raizel Bernstein  6/27/1993     unemployed     Thanksgiving
#
#    Favorite Season                     Fun Fact  \
# 3           Summer  Does NOT like yellow cheese
# 11          Summer            Black Belt in TKD
# 13            Fall               I hate running
#
#                               Allergies         Favorite Sport Resides  Year
# 3                  Peanuts and treenuts          rock climbing    D.C.  1992
# 11  Peanuts, cats, pollen, grass, trees               football      NJ  2009
# 13          peanuts, seasonal allergies  watching the bachelor      NJ  1993

# %%
import datetime

# %%
now = pd.to_datetime('now')
df['Birthday'] = pd.to_datetime(df['Birthday'])
df
# Out:
#     id                    Name   Birthday               Occupation  \
# 0    0  Briana Faith Feirstein 1996-10-05        Genetic Counselor
# 1    1     Marc Seth Bernstein 1998-06-24        Software engineer
# 2    2     Nina Rebecca Bigler 1994-04-25  Nonprofit Administrator
# 3    3      Megan Haley Fitter 1992-10-02            PhD Candidate
# 4    4   Eliana Lisa Bernstein 1995-03-31          Project Manager
# 5    5   Ariel Julian Abrahams 1988-01-30             Soundproofer
# 6    6      Rafi Noah Abrahams 1990-08-23                  Student
# 7    7  Juliana Rebecca Biller 1994-06-03         Paraprofessional
# 8    8          Jessica Fitter 1998-05-19                   Banker
# 9    9      Denise Emma Fitter 1994-11-18                Paralegal
# 10  10           Andrew Fitter 2001-02-22                  Student
# 11  11      Sean Pierce Fitter 2009-09-24                  Student
# 12  12   Myles Anderson Fitter 2012-05-15                  Student
# ...

# %%
df.groupby(df['id'])['Name', 'Birthday'].head()
# Out:
#                       Name   Birthday
# 0   Briana Faith Feirstein 1996-10-05
# 1      Marc Seth Bernstein 1998-06-24
# 2      Nina Rebecca Bigler 1994-04-25
# 3       Megan Haley Fitter 1992-10-02
# 4    Eliana Lisa Bernstein 1995-03-31
# 5    Ariel Julian Abrahams 1988-01-30
# 6       Rafi Noah Abrahams 1990-08-23
# 7   Juliana Rebecca Biller 1994-06-03
# 8           Jessica Fitter 1998-05-19
# 9       Denise Emma Fitter 1994-11-18
# 10           Andrew Fitter 2001-02-22
# 11      Sean Pierce Fitter 2009-09-24
# 12   Myles Anderson Fitter 2012-05-15
# 13        Raizel Bernstein 1993-06-27

# %%
# for birthday in df['Birthday']:
#     age = now - birthday
#     print(age.astype('<m8[Y]'))
df['Age'] = (now - df['Birthday']).astype('<m8[Y]')

# %%
# prac = pd.to_datetime(df['Birthday'], format='%m/%d/%Y')
# df['prac'] = (now - prac)
# df['prac']

# %%
df.head(14)
# Out:
#     id                    Name   Birthday               Occupation  \
# 0    0  Briana Faith Feirstein 1996-10-05        Genetic Counselor
# 1    1     Marc Seth Bernstein 1998-06-24        Software engineer
# 2    2     Nina Rebecca Bigler 1994-04-25  Nonprofit Administrator
# 3    3      Megan Haley Fitter 1992-10-02            PhD Candidate
# 4    4   Eliana Lisa Bernstein 1995-03-31          Project Manager
# 5    5   Ariel Julian Abrahams 1988-01-30             Soundproofer
# 6    6      Rafi Noah Abrahams 1990-08-23                  Student
# 7    7  Juliana Rebecca Biller 1994-06-03         Paraprofessional
# 8    8          Jessica Fitter 1998-05-19                   Banker
# 9    9      Denise Emma Fitter 1994-11-18                Paralegal
# 10  10           Andrew Fitter 2001-02-22                  Student
# 11  11      Sean Pierce Fitter 2009-09-24                  Student
# 12  12   Myles Anderson Fitter 2012-05-15                  Student
# ...

# %%
plt.hist(df['Age'], bins = 18, align = 'mid', rwidth = .9)


# plt.set_title('Ages Amongst Cousins')
plt.xlabel('Age')
plt.ylabel('Number of Cousins')
plt.yticks([1,2,3])
plt.xticks(range(7,35))

plt.show()

plt.savefig('cousinhistogram')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
# &lt;Figure size 432x288 with 0 Axes&gt;

# %%
df['Age'].describe()
# Out:
# count    14.000000
# mean     23.214286
# std       6.704517
# min       8.000000
# 25%      22.000000
# 50%      25.000000
# 75%      26.750000
# max      32.000000
# Name: Age, dtype: float64

# %%
plt.boxplot(df['Age'], vert=False)

# fig, ax = plt.boxplot(df['Age'])
# plt.set_title('Age Amongst Cousins')
plt.xlabel('Age')

plt.savefig('cousinboxplot')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
now = pd.to_datetime('now')
df['Birthday'] = pd.to_datetime(df['Birthday'])
df
# Out:
#     id                    Name   Birthday               Occupation  \
# 0    0  Briana Faith Feirstein 1996-10-05        Genetic Counselor
# 1    1     Marc Seth Bernstein 1998-06-24        Software engineer
# 2    2     Nina Rebecca Bigler 1994-04-25  Nonprofit Administrator
# 3    3      Megan Haley Fitter 1992-10-02            PhD Candidate
# 4    4   Eliana Lisa Bernstein 1995-03-31          Project Manager
# 5    5   Ariel Julian Abrahams 1988-01-30             Soundproofer
# 6    6      Rafi Noah Abrahams 1990-08-23                  Student
# 7    7  Juliana Rebecca Biller 1994-06-03         Paraprofessional
# 8    8          Jessica Fitter 1998-05-19                   Banker
# 9    9      Denise Emma Fitter 1994-11-18                Paralegal
# 10  10           Andrew Fitter 2001-02-22                  Student
# 11  11      Sean Pierce Fitter 2009-09-24                  Student
# 12  12   Myles Anderson Fitter 2012-05-15                  Student
# ...

# %%
def zodiac_sign(day, month):
    if month == 12:
        astro_sign = 'sagittarius' if (day < 22) else 'capricorn'
    elif month == 1:
        astro_sign = 'capricorn' if (day < 20) else 'aquarius'
    elif month == 2:
        astro_sign = 'aquarius' if (day < 19) else 'pisces'
    elif month == 3:
        astro_sign = 'pisces' if (day < 21) else 'aries'
    elif month == 4:
        astro_sign = 'aries' if (day < 20) else 'taurus'
    elif month == 5:
        astro_sign = 'taurus' if (day < 21) else 'gemini'
    elif month == 6:
        astro_sign = 'gemini' if (day < 21) else 'cancer'
    elif month == 7:
        astro_sign = 'cancer' if (day < 23) else 'leo'
    elif month == 8:
        astro_sign = 'leo' if (day < 23) else 'virgo'
    elif month == 9:
	    astro_sign = 'virgo' if (day < 23) else 'libra'
    elif month == 10:
        astro_sign = 'libra' if (day < 23) else 'scorpio'
    elif month == 11:
	    astro_sign = 'scorpio' if (day < 22) else 'sagittarius'
    # print("Your Astrological sign is: ", astro_sign)
    return astro_sign

# %%
zodiac_sign(27, 6)
# Out:
# &#39;cancer&#39;

# %%
months = list(df['Birthday'].dt.month)
days = list(df['Birthday'].dt.day)
names = list(df['Name'])
# for i in month:
#     print(i, type(i))
# print(list(day))
zipped = zip(names, days, months)
# print(zipped)
# for person in zipped:
#     print(person)

# %%
# print(zipped)
cousins = []
for person in zipped:
    #print(person)
    sign = zodiac_sign(person[1], person[2])
    cousins.append([person[0], sign])
cousins
# Out:
# [[&#39;Briana Faith Feirstein&#39;, &#39;libra&#39;],
#  [&#39;Marc Seth Bernstein&#39;, &#39;cancer&#39;],
#  [&#39;Nina Rebecca Bigler&#39;, &#39;taurus&#39;],
#  [&#39;Megan Haley Fitter&#39;, &#39;libra&#39;],
#  [&#39;Eliana Lisa Bernstein&#39;, &#39;aries&#39;],
#  [&#39;Ariel Julian Abrahams&#39;, &#39;aquarius&#39;],
#  [&#39;Rafi Noah Abrahams&#39;, &#39;virgo&#39;],
#  [&#39;Juliana Rebecca Biller&#39;, &#39;gemini&#39;],
#  [&#39;Jessica Fitter&#39;, &#39;taurus&#39;],
#  [&#39;Denise Emma Fitter&#39;, &#39;scorpio&#39;],
#  [&#39;Andrew Fitter&#39;, &#39;pisces&#39;],
#  [&#39;Sean Pierce Fitter&#39;, &#39;libra&#39;],
#  [&#39;Myles Anderson Fitter&#39;, &#39;taurus&#39;],
#  [&#39;Raizel Bernstein&#39;, &#39;cancer&#39;]]

# %%
signs = pd.DataFrame(cousins, columns=['name', 'sign'])
signs.head(14)
# Out:
#                       name      sign
# 0   Briana Faith Feirstein     libra
# 1      Marc Seth Bernstein    cancer
# 2      Nina Rebecca Bigler    taurus
# 3       Megan Haley Fitter     libra
# 4    Eliana Lisa Bernstein     aries
# 5    Ariel Julian Abrahams  aquarius
# 6       Rafi Noah Abrahams     virgo
# 7   Juliana Rebecca Biller    gemini
# 8           Jessica Fitter    taurus
# 9       Denise Emma Fitter   scorpio
# 10           Andrew Fitter    pisces
# 11      Sean Pierce Fitter     libra
# 12   Myles Anderson Fitter    taurus
# 13        Raizel Bernstein    cancer

# %%
libra = len(signs.loc[signs['sign'] == 'libra'])
libra
# Out:
# 3

# %%
cancer = len(signs.loc[signs['sign'] == 'cancer'])
cancer
# Out:
# 2

# %%
taurus = len(signs.loc[signs['sign'] == 'taurus'])
taurus
# Out:
# 3

# %%
aries = len(signs.loc[signs['sign'] == 'aries'])
aries
# Out:
# 1

# %%
aquarius = len(signs.loc[signs['sign'] == 'aquarius'])
aquarius
# Out:
# 1

# %%
virgo = len(signs.loc[signs['sign'] == 'virgo'])
virgo
# Out:
# 1

# %%
gemini = len(signs.loc[signs['sign'] == 'gemini'])
gemini
# Out:
# 1

# %%
scorpio = len(signs.loc[signs['sign'] == 'scorpio'])
scorpio
# Out:
# 1

# %%
pisces = len(signs.loc[signs['sign'] == 'pisces'])
pisces
# Out:
# 1

# %%
fig, ax = plt.subplots()
x = ['aquarius', 'pisces', 'aries', 'taurus', 'gemini', 'cancer', 'leo', 'virgo', 'libra', 'scorpio', 'sagittarius', 'capricorn']
y = [aquarius, pisces, aries, taurus, gemini, cancer, 0, virgo, libra, scorpio, 0, 0]
color = ['deepskyblue', 'purple', 'red', 'midnightblue', 'green', 'orange', 'yellow', 'magenta', 'lightsalmon', 'brown', 'darkolivegreen', 'brown']
plt.bar(x, y, color = color)

ax.set_title('Astrology Signs')
ax.set_xlabel('Signs')
ax.set_ylabel('Number of Cousins')
plt.xticks(rotation=50);
ax.set_yticks([1,2,3])

plt.savefig('astrology')
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
df.head()
# Out:
#    id                    Name   Birthday               Occupation  \
# 0   0  Briana Faith Feirstein  10/5/1996        Genetic Counselor
# 1   1     Marc Seth Bernstein  6/24/1998        Software engineer
# 2   2     Nina Rebecca Bigler  4/25/1994  Nonprofit Administrator
# 3   3      Megan Haley Fitter  10/2/1992            PhD Candidate
# 4   4   Eliana Lisa Bernstein  3/31/1995          Project Manager
#
#   Favorite Holiday Favorite Season                                Fun Fact  \
# 0     Thanksgiving            Fall                      Never broke a bone
# 1     Thanksgiving            Fall                           Learning Bass
# 2     Thanksgiving          Spring  Learning to perfect the Israeli quiche
# 3     Thanksgiving          Summer             Does NOT like yellow cheese
# 4     Thanksgiving          Spring                                     NaN
#
#               Allergies       Favorite Sport        Resides
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x='Favorite Holiday',data=df, hue='Resides')
# Out:
# <AxesSubplot:xlabel='Favorite Holiday', ylabel='count'>
