# %%
import pandas as pd 
import matplotlib as plt
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv('../data/netflix_titles.csv')

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df = pd.read_csv('../data/mbti_1.csv')

# %%
df
# Out:
#       type                                              posts
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1     ENTP  'I'm finding the lack of me in these posts ver...
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4     ENTJ  'You're fired.|||That's another silly misconce...
# ...    ...                                                ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...
# 8671  ENFP  'So...if this thread already exists someplace ...
# 8672  INTP  'So many questions when i do these things.  I ...
# 8673  INFP  'I am very conflicted right now when it comes ...
# 8674  INFP  'It has been too long since I have been on per...
#
# [8675 rows x 2 columns]

# %%
df[df['type'] == 'INTP']
# Out:
#       type                                              posts
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...
# 9     INTP  'https://www.youtube.com/watch?v=w8-egj0y8Qs||...
# 14    INTP  'Basically this...  https://youtu.be/1pH5c1Jkh...
# 15    INTP  'Your comment screams INTJ, bro. Especially th...
# 20    INTP  'Steve Job's was recognized for his striving f...
# ...    ...                                                ...
# 8640  INTP  'This is a great thread... I find it interesti...
# 8647  INTP  Socionics picked up on this.  They call it vis...
# 8663  INTP  'doesn't matter, you don't have a choice, Elec...
# 8664  INTP  'https://www.youtube.com/watch?v=7zsMdi714mI||...
# 8672  INTP  'So many questions when i do these things.  I ...
#
# [1304 rows x 2 columns]

# %%
df[df['type'] == 'INTP']['posts'][:1]
# Out:
# 2    'Good one  _____   https://www.youtube.com/wat...
# Name: posts, dtype: object

# %%
df = pd.read_csv('../data/colors_and_palettes.csv')

# %%
df.head(9)
# Out:
#   BASE_COLORS TABLEAU_COLORS     CSS4_COLORS             XKCD_COLORS  \
# 0           b       tab:blue       aliceblue        xkcd:cloudy blue
# 1           g     tab:orange    antiquewhite  xkcd:dark pastel green
# 2           r      tab:green            aqua               xkcd:dust
# 3           c        tab:red      aquamarine      xkcd:electric lime
# 4           m     tab:purple           azure        xkcd:fresh green
# 5           y      tab:brown           beige     xkcd:light eggplant
# 6           k       tab:pink          bisque        xkcd:nasty green
# 7           w       tab:gray           black  xkcd:really light blue
# 8         NaN      tab:olive  blanchedalmond                xkcd:tea
#
#   PALETTE_COLORS
# 0         Accent
# 1       Accent_r
# 2          Blues
# 3        Blues_r
# 4           BrBG
# 5         BrBG_r
# 6           BuGn
# 7         BuGn_r
# 8           BuPu

# %%
# df.head(1000)
# Out:
# 610                xkcd:purpley blue                 NaN
# 611                xkcd:light indigo                 NaN
# 612                 xkcd:swamp green                 NaN
# 613                 xkcd:brown green                 NaN
# 614                 xkcd:dark maroon                 NaN
# 615                  xkcd:hot purple                 NaN
# 616           xkcd:dark forest green                 NaN
# 617                  xkcd:faded blue                 NaN
# 618                  xkcd:drab green                 NaN
# 619            xkcd:light lime green                 NaN
# 620                  xkcd:snot green                 NaN
# 621                   xkcd:yellowish                 NaN
# 622            xkcd:light blue green                 NaN
# 623                    xkcd:bordeaux                 NaN
# 624                 xkcd:light mauve                 NaN
# 625                       xkcd:ocean                 NaN
# ...
