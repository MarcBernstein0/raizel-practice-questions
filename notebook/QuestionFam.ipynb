# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Questionnaire.csv')

# %%
df
# Out:
# -04-25
# 14            1994-04-25
# 15            1937-04-20
# 16            2012-05-15
# 17            1965-02-05
# 18            1988-01-30
# 19            2012-05-15
# 20            1965-02-05
# 21            1978-01-11
# 22            2021-05-19
# 23            2021-05-19
#
#    Do you have pets? How many? What kind (cat, dog, etc), provide names  \
# 0                                                  No
# 1                                               Nope
# 2                                                  no
# 3                                                  No
# 4                                                Nope
# 5                                             No pets
# 6                                                  No
# 7                                             No pets
# 8   1 mini poodle named Lexie (nicknames: fluffern...
# 9                                             One dog
# 10                                                NaN
# 11                                                 No
# 12                                  Fuzz (cat, age 8)
# 13                                 Plant, 1, menashe
# 14                                 Plant, 1, menashe
# 15                                                 NO
# 16                                                 No
# 17                                       1 dog Lexie
# 18                                         1 Kiwi Dog
# 19                                                 No
# 20                                       1 dog Lexie
# 21                                                 No
# 22                             Dog, little girl lexie
# 23                             Dog, little girl lexie
#
#    If you can have any super power what power would you have?  \
# 0                                       Teleportation
# 1                                             Flying
# 2                                    healing the sick
# 3                                       Teleportation
# 4                     The ability to grow money trees
# 5                                        Invisibility
# 6                                       Teleportation
# 7                              Keep my family healthy
# 8                  Pause time so I could workout more
# 9                                     To be invisible
# 10                                     Teleportation
# 11                                  Control over time
# 12                                       talk to bugs
# 13                                     Teleportation
# 14                                     Teleportation
# 15                 To eliminate the pandemic forever.
# 16                 To shoot lightning out of my hands
# 17                                           Healing
# 18                                                Fly
# 19                 To shoot lightning out of my hands
# 20                                           Healing
# 21                                     ability to fly
# 22                                             Flying
# 23                                             Flying
#
#    What are your top 3 activities to do (hobbies, sports, crafts, etc)?  \
# 0                          Frisbee, eatting, sleeping
# 1                          Reading, yoga, crocheting
# 2                             read, walking, shopping
# 3            Cooking, watching hockey, bravo tv shows
# 4   Play video games, play football, watch YouTube/tv
# 5                             Read, run, watch sports
# 6                          Frisbee, eatting, sleeping
# 7                           Read, travel, play bridge
# 8    Obstacle racing, rock climbing, drinking tequila
# 9                Taking nature walks, painting,crafts
# 10                  Video Games, Running, Watching TV
# 11                         Hiking, astronomy, trumpet
# 12  board games and video games, hike and camp, li...
# 13                          Dance, drawing, ping pong
# 14                          Dance, drawing, ping pong
# 15           Painting, writing poetry, reading books.
# 16  Playing video games, sports, spending time wit...
# 17                                                NaN
# 18                      Gaming, Nature Walks, Reading
# 19  Playing video games, sports, spending time wit...
# 20                                                NaN
# 21               walking, reading, listening to music
# 22                        Reading, walking, traveling
# 23                        Reading, walking, traveling
#
#    What is your favorite holiday? Introvert or Extrovert Podcast or Music  \
# 0                    Thanksgiving              Introvert            Music
# 1                   Thanksgiving               Extrovert            Music
# 2                    thanksgiving              Introvert          Podcast
# 3                   Thanksgiving               Extrovert            Music
# 4              Thanksgiving (duh)              Introvert            Music
# 5                   Thanksgiving               Introvert          Podcast
# 6                    Thanksgiving              Introvert            Music
# 7                   Rosh Hashanah              Extrovert          Podcast
# 8                    Thanksgiving              Extrovert            Music
# 9                         Sabbath              Extrovert            Music
# 10                   Thanksgiving              Introvert            Music
# 11                    My birthday              Introvert            Music
# 12               jewish christmas              Introvert            Music
# 13                  Thanksgiving               Introvert            Music
# 14                  Thanksgiving               Introvert            Music
# 15                      Channukah              Introvert            Music
# 16                       Chanukah              Extrovert            Music
# 17                  Thanksgiving               Introvert            Music
# 18                   Thanksgiving              Introvert          Podcast
# 19                       Chanukah              Extrovert            Music
# 20                  Thanksgiving               Introvert            Music
# 21                    My birthday              Extrovert            Music
# 22                   Thanksgiving              Extrovert            Music
# 23                   Thanksgiving              Extrovert            Music
#
#     ... If Rafi and Jeffrey were playing a board game who would win?  \
# 0   ...                                            Jeffrey
# 1   ...                                            Jeffrey
# 2   ...                                               Rafi
# 3   ...                                            Jeffrey
# 4   ...                                               Rafi
# 5   ...                                            Jeffrey
# 6   ...                                            Jeffrey
# 7   ...                                            Jeffrey
# 8   ...                                               Rafi
# 9   ...                                            Jeffrey
# 10  ...                                            Jeffrey
# 11  ...                                            Jeffrey
# 12  ...                                            Jeffrey
# 13  ...                                                NaN
# 14  ...                                                NaN
# 15  ...                                               Rafi
# 16  ...                                               Rafi
# 17  ...                                            Jeffrey
# 18  ...                                               Rafi
# 19  ...                                               Rafi
# 20  ...                                            Jeffrey
# 21  ...                                               Rafi
# 22  ...                                            Jeffrey
# 23  ...                                            Jeffrey
#
#    Besides Anita Pola and Juan, which relative knows the most Spanish?  \
# 0                                           Beatrice
# 1      Yo hablo español mejor que los otros;) jajaja
# 2                                                Aida
# 3                                                Juan
# 4                                         Sean Fitter
# 5                                           Alex shub
# 6                                           Beatrice
# 7                                                Sean
# 8                                                Sean
# 9                                                Sean
# 10                                               Aida
# 11                                             Miriam
# 12                                           aida lol
# 13                                                Jay
# 14                                                Jay
# 15                                             Miriam
# 16                                               Bebe
# 17                                               Aida
# 18                           Mimi payed me to say her
# 19                                               Bebe
# 20                                               Aida
# 21                                             Miriam
# 22                                            Jeffrey
# 23                                            Jeffrey
#
#    Which relative do you think is most likely to win mario kart?  \
# 0                                              Eliana
# 1                                                Rafi
# 2                                                Marc
# 3                                            Not marc
# 4                                                Marc
# 5                                                Marc
# 6                                              Eliana
# 7                                               Anita
# 8                                                Marc
# 9                                              Briana
# 10                                               Marc
# 11                                               Marc
# 12                     marc :( unless nick is playing
# 13                                               Sean
# 14                                               Sean
# 15                                      I don´t know.
# 16                                               Marc
# 17                                               Mark
# 18                                              Lori
# 19                                               Marc
# 20                                               Mark
# 21                                               Marc
# 22                                             Raizel
# 23                                             Raizel
#
#    Attachment Style                                 Which is best?  \
# 0           Anxious                                Middle children
# 1           Anxious                          Oldest children (duh)
# 2         N/A (idk)                          Oldest children (duh)
# 3         N/A (idk)                              Youngest children
# 4         N/A (idk)                          Oldest children (duh)
# 5            Secure                              Youngest children
# 6           Anxious                                Middle children
# 7            Secure                          Oldest children (duh)
# 8          Avoidant                          Oldest children (duh)
# 9         N/A (idk)                              Youngest children
# 10         Avoidant                              Youngest children
# 11          Anxious  Jessica and Jay (is anyone else a 3rd child?)
# 12           Secure                                Middle children
# 13              NaN                              Youngest children
# 14              NaN                              Youngest children
# 15           Secure                              Youngest children
# 16        N/A (idk)                              Youngest children
# 17           Secure                                Middle children
# 18        N/A (idk)                          Oldest children (duh)
# 19        N/A (idk)                              Youngest children
# 20           Secure                                Middle children
# 21           Secure                              Youngest children
# 22         Avoidant  Jessica and Jay (is anyone else a 3rd child?)
# 23         Avoidant  Jessica and Jay (is anyone else a 3rd child?)
#
#    Which describes you best? Mask or no mask  \
# 0                    Liberal            mask
# 1                    Liberal            mask
# 2                    Liberal            mask
# 3                    Liberal            mask
# 4                    Liberal            mask
# 5                    Liberal            mask
# 6                    Liberal            mask
# 7               Conservative            mask
# 8                    Liberal            mask
# 9                    Liberal            mask
# 10                   Liberal            mask
# 11                   Liberal            mask
# 12                   Liberal            mask
# 13                   Liberal            mask
# 14                   Liberal            mask
# 15              Conservative            mask
# 16                   Liberal            mask
# 17                   Liberal            mask
# 18                   Liberal            mask
# 19                   Liberal            mask
# 20                   Liberal            mask
# 21                   Liberal            mask
# 22                   Liberal            mask
# 23                   Liberal            mask
#
#     Raizel, HOW MANY MORE QUESTIONS ARE THERE?  \
# 0   I expect an open bar at Sean's Bar mitzvah
# 1   I expect an open bar at Sean's Bar mitzvah
# 2                             shut the **** up
# 3   I expect an open bar at Sean's Bar mitzvah
# 4   I expect an open bar at Sean's Bar mitzvah
# 5   I expect an open bar at Sean's Bar mitzvah
# 6   I expect an open bar at Sean's Bar mitzvah
# 7                          I love this survey!
# 8   I expect an open bar at Sean's Bar mitzvah
# 9   I expect an open bar at Sean's Bar mitzvah
# 10  I expect an open bar at Sean's Bar mitzvah
# 11  I expect an open bar at Sean's Bar mitzvah
# 12  I expect an open bar at Sean's Bar mitzvah
# 13  I expect an open bar at Sean's Bar mitzvah
# 14  I expect an open bar at Sean's Bar mitzvah
# 15                         I love this survey!
# 16  I expect an open bar at Sean's Bar mitzvah
# 17  I expect an open bar at Sean's Bar mitzvah
# 18  I expect an open bar at Sean's Bar mitzvah
# 19  I expect an open bar at Sean's Bar mitzvah
# 20  I expect an open bar at Sean's Bar mitzvah
# 21                            shut the **** up
# 22  I expect an open bar at Sean's Bar mitzvah
# 23  I expect an open bar at Sean's Bar mitzvah
#
#                            What is your best failure?  \
# 0   One time raizel and Marc both stole sodas out ...
# 1             Wtf does that mean?! Failure is no fun
# 2          NJ License project sending someone to jail
# 3          Getting rejected by my top 5 grad programs
# 4                    This years March madness bracket
# 5   My MasterCard conversion project at Citi. Did ...
# 6   One time raizel and Marc both stole sodas out ...
# 7                          Not following my instincts
# 8   I work too hard and am too successful and good...
# 9                  Giving in to filling out this form
# 10                             Thinking I am athletic
# 11                                       The bar exam
# 12                                    quitting my job
# 13                                                NaN
# 14                                                NaN
# 15               To understand some of the questions.
# 16                   Trying to create a musical group
# 17                                                NaN
# 18                                           Too many
# 19                   Trying to create a musical group
# 20                                                NaN
# 21                             My first teaching job.
# 22                      I’ve never found the afikomen
# 23                      I’ve never found the afikomen
#
#          Top 3 songs you want to hear at Club Turkey?
# 0   1. Anything Shakira 2. Petron tequila I’m drun...
# 1                      Anything by Justin Timberlake
# 2      Copacabana, Living la vida loca, We are family
# 3           In da club, toxic, discovery channel song
# 4                Tootsie slide, lucid dreams, robbery
# 5   As long as it does not give me a headache, I d...
# 6   1. Anything Shakira 2. Petron tequila I’m drun...
# 7        A Cuban song, a yidish song, an Israeli song
# 8    1. Patron, 2. tequila, 3. I'm drunk on margarita
# 9   Staying alive, living on a prayer , we are the...
# 10             In Da Club, Drop It Like It's Hot, Low
# 11                 New versions of the Rolling Stones
# 12  drivers license, beez in the trap, baby (justi...
# 13                                       Bye bye bye
# 14                                       Bye bye bye
# 15                                   Old Cuban songs.
# 16         Year 3000, burning up, what a man gotta do
# 17                                                NaN
# 18                                       Beyonce only
# 19         Year 3000, burning up, what a man gotta do
# 20                                                NaN
# 21                 1999, Jersey Girl, Brown Eyed Girl
# 22               Drivers license, WAP, patron tequila
# 23               Drivers license, WAP, patron tequila
#
# [24 rows x 34 columns]

# %%
df['What is your name'].unique()
# Out:
# array(['Eliana', 'Miriam Bradman Abrahams', 'Bebe Bernstein', 'Briana',
#        'Sean Fitter', 'Bryan Fitter', 'Ana Fitter', 'Megan',
#        'Sheila Feirstein', 'Marc Bernstein', 'Jay', 'Rafi', 'Nina',
#        'Pola Bradman', 'Myles Fitter', 'Jeffrey', 'Ariel',
#        'Lori Krantz Fitter', 'Jessica Fitter'], dtype=object)

# %%
df['What is your name'].value_counts()
# Out:
# Eliana                     2
# Jessica Fitter             2
# Nina                       2
# Myles Fitter               2
# Jeffrey                    2
# Miriam Bradman Abrahams    1
# Ariel                      1
# Pola Bradman               1
# Sean Fitter                1
# Briana                     1
# Bryan Fitter               1
# Rafi                       1
# Megan                      1
# Jay                        1
# Marc Bernstein             1
# Ana Fitter                 1
# Lori Krantz Fitter         1
# Sheila Feirstein           1
# Bebe Bernstein             1
# Name: What is your name, dtype: int64

# %%
import seaborn as sns
import numpy as np

# %%
df.sort_values(by = 'What is your birthday', ascending = True)
# Out:
# -04-25
# 14            1994-04-25
# 0             1995-03-31
# 6             1995-03-31
# 3             1996-10-05
# 10            1998-06-24
# 4             2009-09-24
# 16            2012-05-15
# 19            2012-05-15
# 22            2021-05-19
# 23            2021-05-19
#
#    Do you have pets? How many? What kind (cat, dog, etc), provide names  \
# 15                                                 NO
# 7                                             No pets
# 1                                               Nope
# 11                                                 No
# 2                                                  no
# 9                                             One dog
# 20                                       1 dog Lexie
# 17                                       1 dog Lexie
# 5                                             No pets
# 21                                                 No
# 18                                         1 Kiwi Dog
# 12                                  Fuzz (cat, age 8)
# 8   1 mini poodle named Lexie (nicknames: fluffern...
# 13                                 Plant, 1, menashe
# 14                                 Plant, 1, menashe
# 0                                                  No
# 6                                                  No
# 3                                                  No
# 10                                                NaN
# 4                                                Nope
# 16                                                 No
# 19                                                 No
# 22                             Dog, little girl lexie
# 23                             Dog, little girl lexie
#
#    If you can have any super power what power would you have?  \
# 15                 To eliminate the pandemic forever.
# 7                              Keep my family healthy
# 1                                             Flying
# 11                                  Control over time
# 2                                    healing the sick
# 9                                     To be invisible
# 20                                           Healing
# 17                                           Healing
# 5                                        Invisibility
# 21                                     ability to fly
# 18                                                Fly
# 12                                       talk to bugs
# 8                  Pause time so I could workout more
# 13                                     Teleportation
# 14                                     Teleportation
# 0                                       Teleportation
# 6                                       Teleportation
# 3                                       Teleportation
# 10                                     Teleportation
# 4                     The ability to grow money trees
# 16                 To shoot lightning out of my hands
# 19                 To shoot lightning out of my hands
# 22                                             Flying
# 23                                             Flying
#
#    What are your top 3 activities to do (hobbies, sports, crafts, etc)?  \
# 15           Painting, writing poetry, reading books.
# 7                           Read, travel, play bridge
# 1                          Reading, yoga, crocheting
# 11                         Hiking, astronomy, trumpet
# 2                             read, walking, shopping
# 9                Taking nature walks, painting,crafts
# 20                                                NaN
# 17                                                NaN
# 5                             Read, run, watch sports
# 21               walking, reading, listening to music
# 18                      Gaming, Nature Walks, Reading
# 12  board games and video games, hike and camp, li...
# 8    Obstacle racing, rock climbing, drinking tequila
# 13                          Dance, drawing, ping pong
# 14                          Dance, drawing, ping pong
# 0                          Frisbee, eatting, sleeping
# 6                          Frisbee, eatting, sleeping
# 3            Cooking, watching hockey, bravo tv shows
# 10                  Video Games, Running, Watching TV
# 4   Play video games, play football, watch YouTube/tv
# 16  Playing video games, sports, spending time wit...
# 19  Playing video games, sports, spending time wit...
# 22                        Reading, walking, traveling
# 23                        Reading, walking, traveling
#
#    What is your favorite holiday? Introvert or Extrovert Podcast or Music  \
# 15                      Channukah              Introvert            Music
# 7                   Rosh Hashanah              Extrovert          Podcast
# 1                   Thanksgiving               Extrovert            Music
# 11                    My birthday              Introvert            Music
# 2                    thanksgiving              Introvert          Podcast
# 9                         Sabbath              Extrovert            Music
# 20                  Thanksgiving               Introvert            Music
# 17                  Thanksgiving               Introvert            Music
# 5                   Thanksgiving               Introvert          Podcast
# 21                    My birthday              Extrovert            Music
# 18                   Thanksgiving              Introvert          Podcast
# 12               jewish christmas              Introvert            Music
# 8                    Thanksgiving              Extrovert            Music
# 13                  Thanksgiving               Introvert            Music
# 14                  Thanksgiving               Introvert            Music
# 0                    Thanksgiving              Introvert            Music
# 6                    Thanksgiving              Introvert            Music
# 3                   Thanksgiving               Extrovert            Music
# 10                   Thanksgiving              Introvert            Music
# 4              Thanksgiving (duh)              Introvert            Music
# 16                       Chanukah              Extrovert            Music
# 19                       Chanukah              Extrovert            Music
# 22                   Thanksgiving              Extrovert            Music
# 23                   Thanksgiving              Extrovert            Music
#
#     ... If Rafi and Jeffrey were playing a board game who would win?  \
# 15  ...                                               Rafi
# 7   ...                                            Jeffrey
# 1   ...                                            Jeffrey
# 11  ...                                            Jeffrey
# 2   ...                                               Rafi
# 9   ...                                            Jeffrey
# 20  ...                                            Jeffrey
# 17  ...                                            Jeffrey
# 5   ...                                            Jeffrey
# 21  ...                                               Rafi
# 18  ...                                               Rafi
# 12  ...                                            Jeffrey
# 8   ...                                               Rafi
# 13  ...                                                NaN
# 14  ...                                                NaN
# 0   ...                                            Jeffrey
# 6   ...                                            Jeffrey
# 3   ...                                            Jeffrey
# 10  ...                                            Jeffrey
# 4   ...                                               Rafi
# 16  ...                                               Rafi
# 19  ...                                               Rafi
# 22  ...                                            Jeffrey
# 23  ...                                            Jeffrey
#
#    Besides Anita Pola and Juan, which relative knows the most Spanish?  \
# 15                                             Miriam
# 7                                                Sean
# 1      Yo hablo español mejor que los otros;) jajaja
# 11                                             Miriam
# 2                                                Aida
# 9                                                Sean
# 20                                               Aida
# 17                                               Aida
# 5                                           Alex shub
# 21                                             Miriam
# 18                           Mimi payed me to say her
# 12                                           aida lol
# 8                                                Sean
# 13                                                Jay
# 14                                                Jay
# 0                                           Beatrice
# 6                                           Beatrice
# 3                                                Juan
# 10                                               Aida
# 4                                         Sean Fitter
# 16                                               Bebe
# 19                                               Bebe
# 22                                            Jeffrey
# 23                                            Jeffrey
#
#    Which relative do you think is most likely to win mario kart?  \
# 15                                      I don´t know.
# 7                                               Anita
# 1                                                Rafi
# 11                                               Marc
# 2                                                Marc
# 9                                              Briana
# 20                                               Mark
# 17                                               Mark
# 5                                                Marc
# 21                                               Marc
# 18                                              Lori
# 12                     marc :( unless nick is playing
# 8                                                Marc
# 13                                               Sean
# 14                                               Sean
# 0                                              Eliana
# 6                                              Eliana
# 3                                            Not marc
# 10                                               Marc
# 4                                                Marc
# 16                                               Marc
# 19                                               Marc
# 22                                             Raizel
# 23                                             Raizel
#
#    Attachment Style                                 Which is best?  \
# 15           Secure                              Youngest children
# 7            Secure                          Oldest children (duh)
# 1           Anxious                          Oldest children (duh)
# 11          Anxious  Jessica and Jay (is anyone else a 3rd child?)
# 2         N/A (idk)                          Oldest children (duh)
# 9         N/A (idk)                              Youngest children
# 20           Secure                                Middle children
# 17           Secure                                Middle children
# 5            Secure                              Youngest children
# 21           Secure                              Youngest children
# 18        N/A (idk)                          Oldest children (duh)
# 12           Secure                                Middle children
# 8          Avoidant                          Oldest children (duh)
# 13              NaN                              Youngest children
# 14              NaN                              Youngest children
# 0           Anxious                                Middle children
# 6           Anxious                                Middle children
# 3         N/A (idk)                              Youngest children
# 10         Avoidant                              Youngest children
# 4         N/A (idk)                          Oldest children (duh)
# 16        N/A (idk)                              Youngest children
# 19        N/A (idk)                              Youngest children
# 22         Avoidant  Jessica and Jay (is anyone else a 3rd child?)
# 23         Avoidant  Jessica and Jay (is anyone else a 3rd child?)
#
#    Which describes you best? Mask or no mask  \
# 15              Conservative            mask
# 7               Conservative            mask
# 1                    Liberal            mask
# 11                   Liberal            mask
# 2                    Liberal            mask
# 9                    Liberal            mask
# 20                   Liberal            mask
# 17                   Liberal            mask
# 5                    Liberal            mask
# 21                   Liberal            mask
# 18                   Liberal            mask
# 12                   Liberal            mask
# 8                    Liberal            mask
# 13                   Liberal            mask
# 14                   Liberal            mask
# 0                    Liberal            mask
# 6                    Liberal            mask
# 3                    Liberal            mask
# 10                   Liberal            mask
# 4                    Liberal            mask
# 16                   Liberal            mask
# 19                   Liberal            mask
# 22                   Liberal            mask
# 23                   Liberal            mask
#
#     Raizel, HOW MANY MORE QUESTIONS ARE THERE?  \
# 15                         I love this survey!
# 7                          I love this survey!
# 1   I expect an open bar at Sean's Bar mitzvah
# 11  I expect an open bar at Sean's Bar mitzvah
# 2                             shut the **** up
# 9   I expect an open bar at Sean's Bar mitzvah
# 20  I expect an open bar at Sean's Bar mitzvah
# 17  I expect an open bar at Sean's Bar mitzvah
# 5   I expect an open bar at Sean's Bar mitzvah
# 21                            shut the **** up
# 18  I expect an open bar at Sean's Bar mitzvah
# 12  I expect an open bar at Sean's Bar mitzvah
# 8   I expect an open bar at Sean's Bar mitzvah
# 13  I expect an open bar at Sean's Bar mitzvah
# 14  I expect an open bar at Sean's Bar mitzvah
# 0   I expect an open bar at Sean's Bar mitzvah
# 6   I expect an open bar at Sean's Bar mitzvah
# 3   I expect an open bar at Sean's Bar mitzvah
# 10  I expect an open bar at Sean's Bar mitzvah
# 4   I expect an open bar at Sean's Bar mitzvah
# 16  I expect an open bar at Sean's Bar mitzvah
# 19  I expect an open bar at Sean's Bar mitzvah
# 22  I expect an open bar at Sean's Bar mitzvah
# 23  I expect an open bar at Sean's Bar mitzvah
#
#                            What is your best failure?  \
# 15               To understand some of the questions.
# 7                          Not following my instincts
# 1             Wtf does that mean?! Failure is no fun
# 11                                       The bar exam
# 2          NJ License project sending someone to jail
# 9                  Giving in to filling out this form
# 20                                                NaN
# 17                                                NaN
# 5   My MasterCard conversion project at Citi. Did ...
# 21                             My first teaching job.
# 18                                           Too many
# 12                                    quitting my job
# 8   I work too hard and am too successful and good...
# 13                                                NaN
# 14                                                NaN
# 0   One time raizel and Marc both stole sodas out ...
# 6   One time raizel and Marc both stole sodas out ...
# 3          Getting rejected by my top 5 grad programs
# 10                             Thinking I am athletic
# 4                    This years March madness bracket
# 16                   Trying to create a musical group
# 19                   Trying to create a musical group
# 22                      I’ve never found the afikomen
# 23                      I’ve never found the afikomen
#
#          Top 3 songs you want to hear at Club Turkey?
# 15                                   Old Cuban songs.
# 7        A Cuban song, a yidish song, an Israeli song
# 1                      Anything by Justin Timberlake
# 11                 New versions of the Rolling Stones
# 2      Copacabana, Living la vida loca, We are family
# 9   Staying alive, living on a prayer , we are the...
# 20                                                NaN
# 17                                                NaN
# 5   As long as it does not give me a headache, I d...
# 21                 1999, Jersey Girl, Brown Eyed Girl
# 18                                       Beyonce only
# 12  drivers license, beez in the trap, baby (justi...
# 8    1. Patron, 2. tequila, 3. I'm drunk on margarita
# 13                                       Bye bye bye
# 14                                       Bye bye bye
# 0   1. Anything Shakira 2. Petron tequila I’m drun...
# 6   1. Anything Shakira 2. Petron tequila I’m drun...
# 3           In da club, toxic, discovery channel song
# 10             In Da Club, Drop It Like It's Hot, Low
# 4                Tootsie slide, lucid dreams, robbery
# 16         Year 3000, burning up, what a man gotta do
# 19         Year 3000, burning up, what a man gotta do
# 22               Drivers license, WAP, patron tequila
# 23               Drivers license, WAP, patron tequila
#
# [24 rows x 34 columns]

# %%
sns.barplot(x="Blood Type", data = df, palette="Set3")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1cc04d32ade4> in <module>
# ----> 1 sns.barplot(y="Blood Type", data = df, palette="Set3")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3167 ):
#    3168
# -> 3169     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3170                           estimator, ci, n_boot, units, seed,
#    3171                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1296             warnings.warn(single_var_warning.format("Horizontal", "y"))
#    1297         if require_numeric and y_type != "numeric":
# -> 1298             raise TypeError(nonnumeric_dv_error.format("Vertical", "y"))
#    1299         return "v"
#    1300
#
# TypeError: Vertical orientation requires numeric `y` variable.

# %%
# fig, ax = plt.subplots(figsize = (11,11))
x = df['Blood Type'].keys()
y = df.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c44632e9c95b> in <module>
#       1 # fig, ax = plt.subplots(figsize = (11,11))
#       2 x = df['Blood Type'].keys()
# ----> 3 y = df.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df['Blood Type'].keys()
df['Blood Type'].value_counts()
# Out:
# O           15
# not sure     6
# A            3
# Name: Blood Type, dtype: int64

# %%
df.drop_duplicates(subset='What is your name', keep='first', inplace=True)

# %%
df['Blood Type'].keys()
df['Blood Type'].value_counts()
# Out:
# O           12
# not sure     4
# A            3
# Name: Blood Type, dtype: int64

# %%
df['Blood Type'].index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 7, 8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 21, 22], dtype='int64')

# %%
df['Blood Type'].values
# Out:
# array(['O', 'O', 'O', 'O', 'O', 'O', 'O', 'not sure', 'O', 'A', 'A', 'O',
#        'not sure', 'A', 'O', 'O', 'not sure', 'O', 'not sure'],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.bar(df['Blood Type'].value_counts().index, df['Blood Type'].value_counts().values )
# Out:
# <BarContainer object of 3 artists>

# %%
df['Blood Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
