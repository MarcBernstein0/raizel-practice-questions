# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Questionnaire.csv')

# %%
df
# Out:
# -04-25
# 14            1994-04-25
# 15            1937-04-20
# 16            2012-05-15
# 17            1965-02-05
# 18            1988-01-30
# 19            2012-05-15
# 20            1965-02-05
# 21            1978-01-11
# 22            2021-05-19
# 23            2021-05-19
#
#    Do you have pets? How many? What kind (cat, dog, etc), provide names  \
# 0                                                  No
# 1                                               Nope
# 2                                                  no
# 3                                                  No
# 4                                                Nope
# 5                                             No pets
# 6                                                  No
# 7                                             No pets
# 8   1 mini poodle named Lexie (nicknames: fluffern...
# 9                                             One dog
# 10                                                NaN
# ...
