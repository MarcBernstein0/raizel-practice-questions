# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://en.wikipedia.org/wiki/The_Bachelor_(American_TV_series)')
# page.text

# %%
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# namespaces-label" class="mw-portlet mw-portlet-namespaces vector-menu vector-menu-tabs" id="p-namespaces" role="navigation">
#       <h3 id="p-namespaces-label">
#        <span>
#         Namespaces
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#         <li class="selected" id="ca-nstab-main">
#          <a accesskey="c" href="/wiki/The_Bachelor_(American_TV_series)" title="View the content page [c]">
#           Article
#          </a>
#         </li>
#         <li id="ca-talk">
#          <a accesskey="t" href="/wiki/Talk:The_Bachelor_(American_TV_series)" rel="discussion" title="Discuss improvements to the content page [t]">
#           Talk
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# ...

# %%
for a in soup.find_all('a'):
    print(a.find)
# Out:
#  href="/wiki/The_Bachelorette_India" title="The Bachelorette India">India</a>
# <a href="/wiki/Enga_Veetu_Mapillai" title="Enga Veetu Mapillai">Tamil Nadu</a>
# <a href="/wiki/Bachelor_Pad" title="Bachelor Pad">Bachelor Pad</a>
# <a href="/wiki/Bachelor_in_Paradise_(American_TV_series)" title="Bachelor in Paradise (American TV series)">Bachelor in Paradise</a>
# <a href="/wiki/List_of_Bachelor_in_Paradise_(American_TV_series)_episodes" title="List of Bachelor in Paradise (American TV series) episodes">seasons</a>
# <a href="/wiki/Bachelor_in_Paradise_(American_season_1)" title="Bachelor in Paradise (American season 1)">1</a>
# <a href="/wiki/Bachelor_in_Paradise_(American_season_2)" title="Bachelor in Paradise (American season 2)">2</a>
# <a href="/wiki/Bachelor_in_Paradise_(American_season_3)" title="Bachelor in Paradise (American season 3)">3</a>
# <a href="/wiki/Bachelor_in_Paradise_(American_season_4)" title="Bachelor in Paradise (American season 4)">4</a>
# ...
