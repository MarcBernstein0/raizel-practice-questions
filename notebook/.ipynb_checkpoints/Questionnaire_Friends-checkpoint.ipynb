# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Questionnaire_Friends.csv')

# %%
df
# Out:
#                     Timestamp What is your name Blood Type  \
# 0  2021/04/23 12:53:44 PM AST            CayCay          O
# 1  2021/04/25 12:51:26 PM AST  Nicole Boschetti          O
# 2   2021/04/28 8:56:16 PM AST           Raizel           A
#
#   What is your birthday Do you have pets?   How many pets?  \
# 0            1993-08-12                yes               1
# 1            1993-01-26                yes               2
# 2            1993-06-27                 no               0
#
#   What animal is your pet (ex. cat, dog, fish, etc.)  \
# 0                                                Dog
# 1                                 Frog 🐸& Tortoise 🐢
# 2                                                NaN
#
#   If you can have any super power what power would you have?  \
# 0                                       Invisibility
# 1                                    invulnerability
# 2  To eat anything and as much as I want while be...
#
# ...

# %%
# pd.set_option('display.max_columns', None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Blood Type', fontsize = 22, color = 'red')
plt.yticks(np.arange(0, 4))
plt.xlabel('Blood Type', fontdict={'fontsize': 15})
plt.ylabel('Amount of Friends', fontdict={'fontsize': 15})
plt.bar(df['Blood Type'].value_counts().index, df['Blood Type'].value_counts().values, color = ['goldenrod', 'silver'])
# Out:
# <BarContainer object of 2 artists>

# %%
df['Month'] = df['What is your birthday'].map(lambda x: x.replace('/', '')[-5:-3])
df['Month']
# Out:
# 0    08
# 1    01
# 2    06
# Name: Month, dtype: object

# %%
def month(df):
    months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    
    birthday_months = []
    for month in df['Month']:
        birthday_months.append(int(month)-1)
    
    birthday_months.sort()
    
    return list(map(lambda x: months[x], birthday_months))

# %%
from collections import Counter

months = Counter(month(df)) # Counter creates a Counter type which is a wrapper for a dictionary 
                            # that counts repeat elements in a list
print(months)

fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Birth Month', fontsize = 22, color = 'black')
plt.yticks(np.arange(0, 4))
plt.xlabel('Birthday Month', fontdict={'fontsize': 15})
plt.ylabel('Amount of Friends', fontdict={'fontsize': 15})
plt.bar(months.keys(), months.values(), color = ['lavender', 'cornflowerblue', 'lightcoral'])
# Out:
# Counter({'January': 1, 'June': 1, 'August': 1})
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Astrology', fontsize = 22)
plt.yticks(np.arange(0, 4))
plt.xlabel('Signs', fontdict={'fontsize': 15})
plt.ylabel('Amount of Friends', fontdict={'fontsize': 15})
plt.bar(df["What's your sign?"].value_counts().index, df["What's your sign?"].value_counts().values, color = ['lavender', 'cornflowerblue', 'lightcoral'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Pets', fontsize = 24)
plt.yticks(np.arange(0, 4))
plt.xlabel('Do you have pets?', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Do you have pets? '].value_counts().index, df['Do you have pets? '].value_counts().values, color = ['goldenrod', 'silver'])
# Out:
# <BarContainer object of 2 artists>

# %%
df['What animal is your pet (ex. cat, dog, fish, etc.)'].value_counts()
# Out:
# Frog 🐸& Tortoise 🐢    1
# Dog                   1
# Name: What animal is your pet (ex. cat, dog, fish, etc.), dtype: int64

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'What is your pet?', fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Type of Pet', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['What animal is your pet (ex. cat, dog, fish, etc.)'].value_counts().index, df['What animal is your pet (ex. cat, dog, fish, etc.)'].value_counts().values,
       color = ['mediumspringgreen', 'rosybrown'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Superpower', fontsize = 25)
plt.xticks(fontsize = 12.8, rotation = 45)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Superpower', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['If you can have any super power what power would you have?'].value_counts().index, df['If you can have any super power what power would you have?'].value_counts().values,
       color = ['black', 'dimgray', 'whitesmoke'])
# Out:
# <BarContainer object of 3 artists>

# %%
df['What are your top 3 activities to do (hobbies, sports, crafts, etc)?'].values
# Out:
# array(['Dance, bask in sunshine, eat',
#        '1. Exercise (Running, Yoga, Strength Train)  2. Reading/Audiobooks  3. Braiding my hair *learning*',
#        'sit outside, run, procrastinate looking for jobs'], dtype=object)

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Favorite Holiday', fontsize = 25)
plt.xticks(fontsize = 14, rotation = 0)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Holiday', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['What is your favorite holiday?'].value_counts().index, df['What is your favorite holiday?'].value_counts().values,
       color = ['sienna', 'red', 'darkorange'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Introvert or Extrovert (forgot ambivert option ... my b)', fontsize = 25)
plt.xticks(fontsize = 14, rotation = 0)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel(':D', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Introvert or Extrovert'].value_counts().index, df['Introvert or Extrovert'].value_counts().values,
       color = ['deeppink', 'pink'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Music or Podcast', fontsize = 25)
plt.xticks(fontsize = 16, rotation = 0)
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Podcast or Music'].value_counts().index, df['Podcast or Music'].value_counts().values,
       color = ['dodgerblue'])
# Out:
# <BarContainer object of 1 artists>

# %%
def clean_string(s):
    try:
        i = s.index('-')
        return s[:i]
    except:
        return s

# %%
df['trip'] = df['Next trip the girls (us) should take / where should we go? '].map(clean_string)
df['trip']
# Out:
# 0         Austin
# 1      Phoenicia
# 2    lake placid
# Name: trip, dtype: object

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Next trip the girls (us) should take / where should we go?', fontsize = 25)
plt.xticks(fontsize = 14, rotation = 90)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel(':D', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['trip'].value_counts().index, df['trip'].value_counts().values,
       color = ['deeppink'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = 'Apple vs Non-Apple Products', fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 0)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Product', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['apple products or not apple products'].value_counts().index, df['apple products or not apple products'].value_counts().values,
       color = ['silver', 'midnightblue'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "What's Your Cup of Tea", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 0)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Drank', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['coffee or tea'].value_counts().index, df['coffee or tea'].value_counts().values,
       color = ['peru', 'mediumpurple'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Starbs or Dunkin or Bubble Tea", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 0)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Drank', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Which is best?'].value_counts().index, df['Which is best?'].value_counts().values,
       color = ['green', 'magenta', 'turquoise'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Alcholic Beverage", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 0)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Drank', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Favorite beverage to order at a bar?'].value_counts().index, df['Favorite beverage to order at a bar?'].value_counts().values,
       color = ['cyan', 'deepskyblue', 'dodgerblue'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Secret Talent", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 15)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Secret Talent', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df["What's your secret talent?"].value_counts().index, df["What's your secret talent?"].value_counts().values,
       color = ['plum', 'darkorchid', 'darkmagenta'])
# Out:
# <BarContainer object of 3 artists>

# %%
print(df['Most creative use of emojis'][0])
print(df['Most creative use of emojis'][1])
print(df['Most creative use of emojis'][2])
# Out:
# 👁🫀🧠 (I love brains)
# 🌎🌍🌏🌵🌲🍃🌱🌳🍄🌻🪨 [In the spirit of Earth Day]
# Hola 'high emoji' to my favorite crew of old ladies! Are you tired '3x sleep emoji' from too much werk??? Here is a tiny violin song for you: 'violin ok violin emoji', because guess what time it is? '3x watch emoji 3x clock emoji' it's time to turn the f'2x up emoji' tonight!!

# %%
print(df['If magic was real, what spell would you try to learn first?'][0])
print(df['If magic was real, what spell would you try to learn first?'][1])
print(df['If magic was real, what spell would you try to learn first?'][2])
# Out:
# Turn something into an anima
# Cooking spell/Perfect coffee spell
# some spell to rid my body of anything unhealthy like excessive cholesterol or unknown tumors etc

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Attachment Style", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 11)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Style', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Attachment Style'].value_counts().index, df['Attachment Style'].value_counts().values,
       color = ['chartreuse', 'lightgreen', 'aquamarine'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Birth Order", fontsize = 25)
plt.xticks(fontsize = 0)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Oldest are the Best', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Birth order: select the category you fit into'].value_counts().index, df['Birth order: select the category you fit into'].value_counts().values,
       color = ['royalblue'])
# Out:
# <BarContainer object of 1 artists>

# %%
print(df['What is your best failure?'][0])
print(df['What is your best failure?'][1])
print(df['What is your best failure?'][2])
# Out:
# Giving a patient too much insulin
# Vegetarianism
# the past decade

# %%
print(df["What are you interested in that you feel the rest of us aren't that into or wouldn't be interested in?"][0])
print(df["What are you interested in that you feel the rest of us aren't that into or wouldn't be interested in?"][1])
print(df["What are you interested in that you feel the rest of us aren't that into or wouldn't be interested in?"][2])
# Out:
# Ballroom dancing
# Yoga OR Day drinking and making our own mixed drinks
# the book Between Two Kingdoms: A memoir of a Life Interrupted and Keeping up with the Kardashians

# %%
print(df['What did you google last?'][0])
print(df['What did you google last?'][1])
print(df['What did you google last?'][2])
# Out:
# Cardiac sarcoidosis
# Phoenicia Diner
# generic cover letter images on google

# %%
print(df['What topic could you spend hours talking about?'][0])
print(df['What topic could you spend hours talking about?'][1])
print(df['What topic could you spend hours talking about?'][2])
# Out:
# Trips abroad or the brain
# teaching/science
# some reality tv, greys, running, psychology

# %%
print(df['If you were hired to show tourists what life is really like in Glen Rock, what would you show them?'][0])
print(df['If you were hired to show tourists what life is really like in Glen Rock, what would you show them?'][1])
print(df['If you were hired to show tourists what life is really like in Glen Rock, what would you show them?'][2])
# Out:
# John’s boys on a Friday at 3:45pm
# The park/duck pond!!!!
# "johns at 3:45pm on a friday" ... answer stolen from Cayla

# %%
print(df['What did you think you were going to be in the third grade?'][0])
print(df['What did you think you were going to be in the third grade?'][1])
print(df['What did you think you were going to be in the third grade?'][2])
# Out:
# Astronomer
# President
# professional soccer player

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Friend Most Likely to Get Lost on a Ladies Trip", fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Most likely to get lost during a girls trip?'].value_counts().index, df['Most likely to get lost during a girls trip?'].value_counts().values,
       color = ['mediumturquoise', 'lightgreen'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Glen Rock's Nickname", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = -8)
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df["What's a good nickname for Glen Rock?"].value_counts().index, df["What's a good nickname for Glen Rock?"].value_counts().values,
       color = ['red', 'black'], edgecolor = ['black', 'red'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Enneagram", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 11)
plt.yticks(np.arange(0,9, step=1))
plt.xlabel('Number', fontdict={'fontsize': 16})
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Enneagram number'].value_counts().index, df['Enneagram number'].value_counts().values,
       color = ['olive', 'khaki', 'cornsilk'], edgecolor = ['darkseagreen'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Myers Brigg", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 11)
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends', fontdict={'fontsize': 16})
plt.bar(df['Myers brigg'].value_counts().index, df['Myers brigg'].value_counts().values,
       color = ['indigo', 'mediumvioletred', 'navy'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Which Harry Potter House is for you?", fontsize = 25)
plt.xticks(fontsize = 12.99, rotation = 11)
plt.xlabel('House', fontdict={'fontsize':16})
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('How Many Friends in Each House', fontdict={'fontsize': 16})
plt.bar(df['Which Harry Potter House is for you?'].value_counts().index, df['Which Harry Potter House is for you?'].value_counts().values,
       color = ['darkblue', 'gainsboro', 'goldenrod'])
# Out:
# <BarContainer object of 3 artists>

# %%
print(df['If we were to start a book club, what book would you recommend everyone read?'][0])
print(df['If we were to start a book club, what book would you recommend everyone read?'][1])
print(df['If we were to start a book club, what book would you recommend everyone read?'][2])
# Out:
# The light we cannot see
# I Will Teach You to Be Rich: No Guilt. No Excuses. No BS. Just a 6-Week Program That Works by Ramit Sethi
# Little Secrets by Jennifer Hillier

# %%
print(df['What do you want for Secret Santa?'][0])
print(df['What do you want for Secret Santa?'][1])
print(df['What do you want for Secret Santa?'][2])
# Out:
# Friend ornament
# A hat- baseball cap or beach hat
# mug, maybe a book, ice coffee

# %%
print(df['What makes you stand out?'][0])
print(df['What makes you stand out?'][1])
print(df['What makes you stand out?'][2])
# Out:
# Diverse interests
# Energy
# my big forehead

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Friend Most Likely to Get Pregnant First", fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends Voted', fontdict={'fontsize': 16})
plt.bar(df['Who is most likely to get pregnant first (and keep the baby)?'].value_counts().index, df['Who is most likely to get pregnant first (and keep the baby)?'].value_counts().values,
       color = ['lightgreen','mediumturquoise'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "COVID Vaccine", fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends Vaccinated', fontdict={'fontsize': 16})
plt.bar(df['Which vaccine did you get?'].value_counts().index, df['Which vaccine did you get?'].value_counts().values,
       color = ['bisque','peachpuff'])
# Out:
# <BarContainer object of 2 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Facebook or Instagram or Tiktok or Twitter", fontsize = 25)
plt.xticks(fontsize = 14)
plt.xlabel('Favorite', fontdict = {'fontsize':18})
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends Vaccinated', fontdict={'fontsize': 18})
plt.bar(df['Favorite social media?'].value_counts().index, df['Favorite social media?'].value_counts().values,
       color = ['blue'])
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize = (15, 7.5))
plt.title(label = "Reading", fontsize = 25)
plt.xticks(fontsize = 14)
plt.yticks(np.arange(0,9, step=1))
plt.ylabel('Number of Friends Vaccinated', fontdict={'fontsize': 17})
plt.bar(df['Electronic books or paper books?'].value_counts().index, df['Electronic books or paper books?'].value_counts().values,
       color = ['chocolate'])
# Out:
# <BarContainer object of 2 artists>

# %%
print(df['Describe the best day ever (imagine unlimited funds, access to whatever)'][0])
print('\n')
print(df['Describe the best day ever (imagine unlimited funds, access to whatever)'][1])
print('\n')
print(df['Describe the best day ever (imagine unlimited funds, access to whatever)'][2])
# Out:
# Flying to a tropical destination, lounging on the beach, and having a gorgeous private villa on the water
#
#
# Wake up SUPER early (like 1 am), have a cup of Kona coffee.  Go see the sunrise at Haleakala in a helicopter.  Take a nap on the beach with sea turtles.  Go on a hike at Kīholo Bay (or other hike within reasonable distance that I haven't done in HI yet).  Go have YUMMY fish dinner and shaved ice for dessert.  End day by going star gazing at Mauna Kea MAUNAKEA
#
#
# wake up late but energized bc I got a great nights sleep, a huge breakfast with fruits & eggs & hash browns/home fries & toast & butter & ice coffee, massage in a private room/villa surrounded by the ocean, a day chilling with friends in some beautiful scenic surrounding (maybe jet skiing), outdoor hot tub evening and ice cream, being in love with someone and cuddling on a hammock with the warm summer night weather - no bugs, lots of ice cream but not gaining any weight

# %%
print(df["Name three songs you'd like to listen to if we (the gang) we're all in a car together"][0])
print('\n')
print(df["Name three songs you'd like to listen to if we (the gang) we're all in a car together"][1])
print('\n')
print(df["Name three songs you'd like to listen to if we (the gang) we're all in a car together"][2])
# Out:
# Best Friend (Doja cat), Good Kisser, what a man gotta do
#
#
# 1.  Absolutely (Story of a Girl)  2.  All the Small Things  3. Slumber Party
#
#
# Girls Just Want to Have Fun by Cyndi Lauper, Calabria by Enur, Come on Eileen by Dexy's Midnight Runners & Kevin Rowland

# %%
print(df["Write a short thank you note to someone."][0])
print('\n')
print(df["Write a short thank you note to someone."][1])
print('\n')
print(df["Write a short thank you note to someone."][2])
# Out:
# Thank you Raizel for giving us daily inspo in Polo and getting us to talk together so frequently!!
#
#
# Dear Cayla,
# Thanks for being so supportive the past few months.  Between your doctor knowledge and your concern for me as afriend you have been a great shoulder to lean on while my dad hasn't been doing well.
# XO Boschetti
#
#
# Thank you Marina Keegan for your essay on the opposite of loneliness. Sorry you died.

# %%
print(df["What's something you learned during quarantine? "][0])
print('\n')
print(df["What's something you learned during quarantine? "][1])
print('\n')
print(df["What's something you learned during quarantine? "][2])
# Out:
# Embroidery!!
#
#
# A lot about myself.
#
#
# Python (coding)
