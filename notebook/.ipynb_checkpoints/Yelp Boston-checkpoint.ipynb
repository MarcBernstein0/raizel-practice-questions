# %%
import pandas as pd
import numpy as np
import requests
import json
#from yelp.client import Client
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# lets try to get some data from yelp!
url = 'https://api.yelp.com/v3'
response = requests.get(url)

# %%
# check the status code
response.status_code
# Out:
# 400

# %%
MY_API_KEY = "227vlJRYFiz_F0D8jfqDblADE28so5LV5HcaRKWz8rn2P1iqCdykA6qXgmaLtPrSBYwq94mKhNt7V0rdWWGJKmBEYec3n80Q6XWRQkvuVbKiETkVLEoNwBRTTzVqX3Yx"

term = 'bagels'
location = 'Boston'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(MY_API_KEY),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response_bagels = requests.get(url, headers=headers, params=url_params)

# %%
print(response_bagels)
# Out:
# <Response [200]>

# %%
print(response_bagels.text)
# Out:
# {"businesses": [{"id": "ue0fG3vQkKpa9HheKVZFvA", "alias": "levend-bagelry-boston-2", "name": "Levend Bagelry", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/0YTeRWCB7o1ELlgSwkXpXw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/levend-bagelry-boston-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA", "review_count": 94, "categories": [{"alias": "bagels", "title": "Bagels"}, {"alias": "bakeries", "title": "Bakeries"}], "rating": 4.0, "coordinates": {"latitude": 42.3619511, "longitude": -71.057115}, "transactions": ["delivery"], "price": "$", "location": {"address1": "100 Hanover St", "address2": "", "address3": null, "city": "Boston", "zip_code": "02108", "country": "US", "state": "MA", "display_address": ["100 Hanover St", "Boston, MA 02108"]}, "phone": "+16179456123", "display_phone": "(617) 945-6123", "distance": 1964.3340646289942}, {"id": "HuQ8YB5eOppEJf3muw_1aQ", "alias": "bagelsaurus-cambridge", "name": "Bagelsaurus", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/rCWKSVIcRu8uekb4T0gOqA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bagelsaurus-cambridge?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA", "review_count": 648, "categories": [{"alias": "bagels", "title": "Bagels"}], "rating": 4.0, "coordinates": {"latitude": 42.3860836095477, "longitude": -71.1195602327565}, "transactions": ["delivery"], "price": "$$", "location": {"address1": "1796 Massachusetts Ave", "address2": "", "address3": "", "city": "Cambridge", "zip_code": "02140", "country": "US", "state": "MA", "display_address": ["1796 Massachusetts Ave", "Cambridge, MA 02140"]}, "phone": "+18572856103", "display_phone": "(857) 285-6103", "distance": 5817.135867467329}, {"id": "YsxfNw7adBpWKXEl0p80xA", "alias": "finagle-a-bagel-boston-6", "name": "Finagle A Bagel", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/5b1XwSHxlVXyJDO1P0CLzw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/finagle-a-bagel-boston-6?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA", "review_count": 154, "categories": [{"alias": "bagels", "title": "Bagels"}, {"alias": "bakeries", "title": "Bakeries"}, {"alias": "coffee", "title": "Coffee & Tea"}], "rating": 3.5, "coordinates": {"latitude": 42.35085, "longitude": -71.07557}, "transactions": ["pickup", "delivery"], "price": "$", "location": {"address1": "535 Boylston St", "address2": "", "address3": "", "city": "Boston", "zip_code": "02116", "country": "US", "state": "MA", "display_address": ["535 Boylston St", "Boston, MA 02116"]}, "phone": "+16172662500", "display_phone": "(617) 266-2500", "distance": 486.85067740703397}, {"id": "f49-SXAS59ghmrGhVabInA", "alias": "katz-bagel-bakery-chelsea", "name": "Katz Bagel Bakery", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/xgp7s6kXlpEZRloSgfdBTA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/katz-bagel-bakery-chelsea?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA", "review_count": 191, "categories": [{"alias": "bagels", "title": "Bagels"}, {"alias": "bakeries", "title": "Bakeries"}], "rating": 4.5, "coordinates": {"latitude": 42.390029, "longitude": -71.036382}, "transactions": ["pickup", "delivery"], "price": "$", "location": {"address1": "139 Park St", "address2": null, "address3": "", "city": "Chelsea", "zip_code": "02150", "country": "US", "state": "MA", "display_address": ["139 Park St", "Chelsea, MA 02150"]}, "phone": "+16178849738", "display_phone": "(617) 884-9738", "distance": 5496.165493145583}, {"id": "1l-vqoiiabP4UWY5llZI_w", "alias": "goldilox-bagels-medford", "name": "Goldilox Bagels", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/fwitkkyv3R79RGHjQvpooA/o.jpg", "is ...

# %%
bagels = response_bagels.text

# %%
bagels = json.loads(bagels)
print(type(bagels))
# Out:
# <class 'dict'>

# %%
bagels
# Out:
# {'businesses': [{'id': 'ue0fG3vQkKpa9HheKVZFvA',
#    'alias': 'levend-bagelry-boston-2',
#    'name': 'Levend Bagelry',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0YTeRWCB7o1ELlgSwkXpXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/levend-bagelry-boston-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 94,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.3619511, 'longitude': -71.057115},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '100 Hanover St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02108',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['100 Hanover St', 'Boston, MA 02108']},
#    'phone': '+16179456123',
#    'display_phone': '(617) 945-6123',
#    'distance': 1964.3340646289942},
#   {'id': 'HuQ8YB5eOppEJf3muw_1aQ',
#    'alias': 'bagelsaurus-cambridge',
#    'name': 'Bagelsaurus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rCWKSVIcRu8uekb4T0gOqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagelsaurus-cambridge?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 648,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.3860836095477,
#     'longitude': -71.1195602327565},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1796 Massachusetts Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Cambridge',
#     'zip_code': '02140',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['1796 Massachusetts Ave', 'Cambridge, MA 02140']},
#    'phone': '+18572856103',
#    'display_phone': '(857) 285-6103',
#    'distance': 5817.135867467329},
#   {'id': 'YsxfNw7adBpWKXEl0p80xA',
#    'alias': 'finagle-a-bagel-boston-6',
#    'name': 'Finagle A Bagel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5b1XwSHxlVXyJDO1P0CLzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/finagle-a-bagel-boston-6?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 154,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.35085, 'longitude': -71.07557},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '535 Boylston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02116',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['535 Boylston St', 'Boston, MA 02116']},
#    'phone': '+16172662500',
#    'display_phone': '(617) 266-2500',
#    'distance': 486.85067740703397},
#   {'id': 'f49-SXAS59ghmrGhVabInA',
#    'alias': 'katz-bagel-bakery-chelsea',
#    'name': 'Katz Bagel Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xgp7s6kXlpEZRloSgfdBTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/katz-bagel-bakery-chelsea?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 191,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.390029, 'longitude': -71.036382},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '139 Park St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chelsea',
#     'zip_code': '02150',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['139 Park St', 'Chelsea, MA 02150']},
#    'phone': '+16178849738',
#    'display_phone': '(617) 884-9738',
#    'distance': 5496.165493145583},
#   {'id': '1l-vqoiiabP4UWY5llZI_w',
#    'alias': 'goldilox-bagels-medford',
#    'name': 'Goldilox Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fwitkkyv3R79RGHjQvpooA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goldilox-bagels-medford?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 73,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.416796, 'longitude': -71.1184622},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '186 Winthrop St',
#     'address2': '',
#     'address3': None,
#     'city': 'Medford',
#     'zip_code': '02155',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['186 Winthrop St', 'Medford, MA 02155']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8592.439251624868},
#   {'id': 'KlNXxqiuxy-TJiouVgUzgw',
#    'alias': 'kupels-bakery-brookline-2',
#    'name': "Kupel's Bakery",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/naZWII0d3rS84W-_YhC6AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kupels-bakery-brookline-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 417,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.34568, 'longitude': -71.12719},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '421 Harvard St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brookline',
#     'zip_code': '02446',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['421 Harvard St', 'Brookline, MA 02446']},
#    'phone': '+16175669528',
#    'display_phone': '(617) 566-9528',
#    'distance': 4600.466377737131},
#   {'id': '4r9MmXSPs7yDOWxf9mTOZA',
#    'alias': 'exodus-bagels-roslindale',
#    'name': 'Exodus Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nS4VjsQLpViKopQN9iV2RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/exodus-bagels-roslindale?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 42,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.2863795040878,
#     'longitude': -71.1447487547187},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2 McCraw St',
#     'address2': None,
#     'address3': '',
#     'city': 'Roslindale',
#     'zip_code': '02131',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['2 McCraw St', 'Roslindale, MA 02131']},
#    'phone': '+16173233354',
#    'display_phone': '(617) 323-3354',
#    'distance': 9123.231291553444},
#   {'id': 'YghPMYNZVYeAHpVGnLN8tg',
#    'alias': 'rosenfeld-bagel-company-newton-center',
#    'name': 'Rosenfeld Bagel Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mqVyD973yE1qh45hkd5a9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rosenfeld-bagel-company-newton-center?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 194,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.32963, 'longitude': -71.19437},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1280 Centre St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newton Center',
#     'zip_code': '02459',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['1280 Centre St', 'Newton Center, MA 02459']},
#    'phone': '+16175278080',
#    'display_phone': '(617) 527-8080',
#    'distance': 10321.348316084313},
#   {'id': 'r1NMCGDR4mXOqPtBOOj3iA',
#    'alias': 'black-sheep-bagel-cafe-cambridge-2',
#    'name': 'Black Sheep Bagel Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fpG20i2MDRIB2-JFmA1Zbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-sheep-bagel-cafe-cambridge-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 146,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.37172, 'longitude': -71.12045},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '56 John F Kennedy St',
#     'address2': '',
#     'address3': None,
#     'city': 'Cambridge',
#     'zip_code': '02138',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['56 John F Kennedy St', 'Cambridge, MA 02138']},
#    'phone': '+16179452189',
#    'display_phone': '(617) 945-2189',
#    'distance': 4840.553073476117},
#   {'id': '0EiJh5yw75hgNozbt5LnXA',
#    'alias': 'mamalehs-delicatessen-cambridge',
#    'name': "Mamaleh's Delicatessen",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QSJOCbxYN45tx0Aq5j-Abw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamalehs-delicatessen-cambridge?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 452,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.3659516, 'longitude': -71.0913369},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Hampshire St',
#     'address2': None,
#     'address3': 'One Kendall Square',
#     'city': 'Cambridge',
#     'zip_code': '02139',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['15 Hampshire St',
#      'One Kendall Square',
#      'Cambridge, MA 02139']},
#    'phone': '+16179583354',
#    'display_phone': '(617) 958-3354',
#    'distance': 2604.0588531585518},
#   {'id': '6dun6w-GWz0ZJWvkjRqZgA',
#    'alias': 'davis-square-hand-crafted-donuts-and-bagels-somerville',
#    'name': 'Davis Square Hand Crafted Donuts & Bagels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y5_0yq41qSBGDdZ2FAezwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/davis-square-hand-crafted-donuts-and-bagels-somerville?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 202,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.39434, 'longitude': -71.12063},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '377 Summer St',
#     'address2': '',
#     'address3': None,
#     'city': 'Somerville',
#     'zip_code': '02144',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['377 Summer St', 'Somerville, MA 02144']},
#    'phone': '+16177640631',
#    'display_phone': '(617) 764-0631',
#    'distance': 6573.8867291418},
#   {'id': 'NpF6tnFh09Xp66DPh3BrGQ',
#    'alias': 'better-bagels-boston',
#    'name': 'Better Bagels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/98UryTtjTyxErBc9gTMLUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/better-bagels-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 98,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 42.351908, 'longitude': -71.046191},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '83A Seaport Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02210',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['83A Seaport Blvd', 'Boston, MA 02210']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2107.81298620398},
#   {'id': 'r65d-mDdDvI2kr79LiE-QA',
#    'alias': 'blunch-boston',
#    'name': 'Blunch',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iBLLKTWXN3MyLVB8q4Ql3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blunch-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 491,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.3354929990873,
#     'longitude': -71.0747301578522},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '59 E Springfield St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02118',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['59 E Springfield St', 'Boston, MA 02118']},
#    'phone': '+16172478100',
#    'display_phone': '(617) 247-8100',
#    'distance': 1402.6981343103912},
#   {'id': 'HZf9MXaVJO-zeDedxN-Fow',
#    'alias': 'turenne-somerville',
#    'name': 'Turenne',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RhCVul9Oee7JjeDsJ6tUIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/turenne-somerville?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 16,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.3797586, 'longitude': -71.094349},
#    'transactions': [],
#    'location': {'address1': '251 Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'Somerville',
#     'zip_code': '02143',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['251 Washington St', 'Somerville, MA 02143']},
#    'phone': '+16177644054',
#    'display_phone': '(617) 764-4054',
#    'distance': 4024.81402420284},
#   {'id': 'HPGgnKeC_lmhELG8Q1F3GA',
#    'alias': 'pavement-coffeehouse-boston',
#    'name': 'Pavement Coffeehouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W12wsDcwPNrOLtheAP2sVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pavement-coffeehouse-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 427,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.3469565156457,
#     'longitude': -71.0884725931989},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1096 Boylston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02215',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['1096 Boylston St', 'Boston, MA 02215']},
#    'phone': '+16172361500',
#    'display_phone': '(617) 236-1500',
#    'distance': 1419.3420100036697},
#   {'id': 'aSfB-o-ryKwyIP_5Rh7lZA',
#    'alias': 'cafe-fresh-bagel-needham-heights',
#    'name': 'Cafe Fresh Bagel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yo1q8XLCzvcDuBd3hZA4uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-fresh-bagel-needham-heights?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 198,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.293528, 'longitude': -71.234793},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '896 Highland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Needham Heights',
#     'zip_code': '02494',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['896 Highland Ave', 'Needham Heights, MA 02494']},
#    'phone': '+17814447444',
#    'display_phone': '(781) 444-7444',
#    'distance': 14740.437885469082},
#   {'id': 'z4PcUANGNEjriFRfRwb9jA',
#    'alias': 'one-mighty-mill-lynn',
#    'name': 'One Mighty Mill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1R0c7ldZbwis7QANdJnr3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/one-mighty-mill-lynn?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 61,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'pretzels', 'title': 'Pretzels'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.463789, 'longitude': -70.942543},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '68 Exchange St',
#     'address2': None,
#     'address3': '',
#     'city': 'Lynn',
#     'zip_code': '01901',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['68 Exchange St', 'Lynn, MA 01901']},
#    'phone': '+17815848648',
#    'display_phone': '(781) 584-8648',
#    'distance': 16669.79630369232},
#   {'id': 'VMgHSvj0abac3sG5T9gwMw',
#    'alias': 'finagle-a-bagel-boston-5',
#    'name': 'Finagle A Bagel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LlVuyZrCEgIx6JkNtbQC9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/finagle-a-bagel-boston-5?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 71,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 42.36137, 'longitude': -71.06823},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '277 Cambridge St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02114',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['277 Cambridge St', 'Boston, MA 02114']},
#    'phone': '+16177261111',
#    'display_phone': '(617) 726-1111',
#    'distance': 1521.961698922479},
#   {'id': '-WG2sv6ApNh1fa7ot-QAEA',
#    'alias': 'archies-new-york-deli-boston',
#    'name': "Archie's New York Deli",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RJr-RN2WsaAbHVv10G5Erg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/archies-new-york-deli-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 178,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.3550721034927,
#     'longitude': -71.0592011686825},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '101 Arch St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02110',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['101 Arch St', 'Boston, MA 02110']},
#    'phone': '+16173305145',
#    'display_phone': '(617) 330-5145',
#    'distance': 1275.0068027427915},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'alias': 'mike-and-pattys-boston-boston',
#    'name': "Mike & Patty's - Boston",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7cknic7LlN3_GX1XGrIB3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mike-and-pattys-boston-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 1778,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.348561, 'longitude': -71.067928},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '12 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02116',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['12 Church St', 'Boston, MA 02116']},
#    'phone': '+16174233447',
#    'display_phone': '(617) 423-3447',
#    'distance': 283.9483626062025},
#   {'id': 'XEdmeFVidV1YjdTgagdCUg',
#    'alias': 'brueggers-bagels-boston-12',
#    'name': "Bruegger's Bagels",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ha7eH2KI_wcJU3BKOXkqGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brueggers-bagels-boston-12?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 64,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.339749960213, 'longitude': -71.108365},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '375 Longwood Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02215',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['375 Longwood Ave', 'Boston, MA 02215']},
#    'phone': '+16177318993',
#    'display_phone': '(617) 731-8993',
#    'distance': 3180.79314746778},
#   {'id': 'rXxC_ZH58EItO3m5PASzEA',
#    'alias': 'render-coffee-boston',
#    'name': 'Render Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WCM6v1mrr8d5N_ql7OqRHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/render-coffee-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 502,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.34115, 'longitude': -71.08149},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '563 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02118',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['563 Columbus Ave', 'Boston, MA 02118']},
#    'phone': '+16172624142',
#    'display_phone': '(617) 262-4142',
#    'distance': 1127.21705249792},
#   {'id': 'dvP90dB0Od0yreOajInkww',
#    'alias': 'pavement-coffeehouse-boston-4',
#    'name': 'Pavement Coffeehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B-VDGpdOT4URVnIDlkn5uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pavement-coffeehouse-boston-4?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 205,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.348843, 'longitude': -71.084396},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '286 Newbury St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02115',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['286 Newbury St', 'Boston, MA 02115']},
#    'phone': '+16178599515',
#    'display_phone': '(617) 859-9515',
#    'distance': 1086.6088538466815},
#   {'id': 'd9INZdRybrmFJYhMM_ZrqA',
#    'alias': 'doughboy-donuts-and-deli-boston',
#    'name': 'Doughboy Donuts & Deli',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kEguAxCWOWG_wB_JghonEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doughboy-donuts-and-deli-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 178,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.340114, 'longitude': -71.056768},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '220 Dorchester Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02127',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['220 Dorchester Ave', 'Boston, MA 02127']},
#    'phone': '+16172698741',
#    'display_phone': '(617) 269-8741',
#    'distance': 1467.5335354244019},
#   {'id': 'teZCxdqC7db5_J6k1txG2A',
#    'alias': '7ate9-bakery-somerville-2',
#    'name': '7ate9 Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bZHosbWdtE_zbBxz9qpYEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/7ate9-bakery-somerville-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 91,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.3897812881346,
#     'longitude': -71.1067319448029},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '199C Highland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Somerville',
#     'zip_code': '02143',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['199C Highland Ave', 'Somerville, MA 02143']},
#    'phone': '+17812189361',
#    'display_phone': '(781) 218-9361',
#    'distance': 5499.82573454498},
#   {'id': 'Y8RD0EARvq0PJ9Tr9YT33A',
#    'alias': 'revival-cafe-kitchen-boston',
#    'name': 'Revival Cafe+Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nM1Ca3yYO_U1iTxOpcYvlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/revival-cafe-kitchen-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 9,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.351703, 'longitude': -71.075416},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '103 Newbury St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02116',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['103 Newbury St', 'Boston, MA 02116']},
#    'phone': '+16176655899',
#    'display_phone': '(617) 665-5899',
#    'distance': 549.483235426067},
#   {'id': '8LySVhnKnCAtMTnwEdgZfg',
#    'alias': 'local-338-bagels-and-coffee-west-roxbury',
#    'name': 'Local 338 Bagels & Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AtX1uKFR9pXvGmP1hVIn3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/local-338-bagels-and-coffee-west-roxbury?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 53,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.28742, 'longitude': -71.14939},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1727 Centre St',
#     'address2': '',
#     'address3': None,
#     'city': 'West Roxbury',
#     'zip_code': '02132',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['1727 Centre St', 'West Roxbury, MA 02132']},
#    'phone': '+18572039770',
#    'display_phone': '(857) 203-9770',
#    'distance': 9296.667934418969},
#   {'id': 'WUW2q1wJ15SlYW2TojBrfA',
#    'alias': 'pavement-coffeehouse-boston-8',
#    'name': 'Pavement Coffeehouse',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pHlMm9XJ8qCLv7WFSz_oRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pavement-coffeehouse-boston-8?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 144,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.3442334895251,
#     'longitude': -71.098496876657},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1334 Boylston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02215',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['1334 Boylston St', 'Boston, MA 02215']},
#    'phone': '+18572637355',
#    'display_phone': '(857) 263-7355',
#    'distance': 2275.4322972476057},
#   {'id': '0G1kNyzpmp9HtotSEJoAMQ',
#    'alias': 'wicked-bagel-lexington',
#    'name': 'Wicked Bagel',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oehbexUFU81bjiXxhBBetw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wicked-bagel-lexington?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 125,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.426228, 'longitude': -71.195773},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '171 Massachusetts Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Lexington',
#     'zip_code': '02420',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['171 Massachusetts Ave', 'Lexington, MA 02420']},
#    'phone': '+17815386506',
#    'display_phone': '(781) 538-6506',
#    'distance': 13437.778281668385},
#   {'id': '9yDOgRWE8duvh21jItz1HQ',
#    'alias': 'the-bagel-table-newton',
#    'name': 'The Bagel Table',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GVuezxTBsq-tAOR3-kgukA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagel-table-newton?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 56,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.323344966032,
#     'longitude': -71.1652919109525},
#    'transactions': ['delivery'],
#    'location': {'address1': '9 Boylston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Newton',
#     'zip_code': '02467',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['9 Boylston St', 'Newton, MA 02467']},
#    'phone': '+16177304500',
#    'display_phone': '(617) 730-4500',
#    'distance': 8277.973915538898},
#   {'id': '-CHlGEdV6LD8dM6-YUgJAQ',
#    'alias': 'einstein-bros-bagels-boston',
#    'name': 'Einstein Bros Bagels',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HCS4ETImYrye_VgTbJDByA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/einstein-bros-bagels-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.350289, 'longitude': -71.105441},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '725 Commonwealth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02215',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['725 Commonwealth Ave', 'Boston, MA 02215']},
#    'phone': '+16173536638',
#    'display_phone': '(617) 353-6638',
#    'distance': 2823.4790041678975},
#   {'id': 'lzm5kCc79wjO7Nqhpsyfiw',
#    'alias': 'the-bagel-table-boston',
#    'name': 'The Bagel Table',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RVqdVIJUV_guBbVtR8badA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bagel-table-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 6,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.3572230047067,
#     'longitude': -71.1457376151889},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '86 Guest St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02135',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['86 Guest St', 'Boston, MA 02135']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 6209.777278031621},
#   {'id': 'v3ECEmKObV783Iupqw1IbQ',
#    'alias': 'magnificent-muffin-and-bagel-shoppe-medford',
#    'name': 'Magnificent Muffin & Bagel Shoppe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/F9pZkwYhvt81IZmgU3nLNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnificent-muffin-and-bagel-shoppe-medford?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 121,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.42177, 'longitude': -71.13378},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '491 High St',
#     'address2': '',
#     'address3': '',
#     'city': 'Medford',
#     'zip_code': '02155',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['491 High St', 'Medford, MA 02155']},
#    'phone': '+17814833511',
#    'display_phone': '(781) 483-3511',
#    'distance': 9671.247107571528},
#   {'id': 'fgBkrXufbmolwKI7batyMw',
#    'alias': 'broad-street-paulies-boston',
#    'name': "Broad Street Paulie's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ASYarpsFinho_A43KSW-4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broad-street-paulies-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 16,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.35787, 'longitude': -71.05336},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '64 Broad St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02109',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['64 Broad St', 'Boston, MA 02109']},
#    'phone': '+16174430490',
#    'display_phone': '(617) 443-0490',
#    'distance': 1841.305015378644},
#   {'id': '-4ORLtNklDgq3MbrOU4tGw',
#    'alias': 'the-square-root-boston',
#    'name': 'The Square Root',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rf4RFT0ySbV7sGUovIexXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-square-root-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 42,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.28676, 'longitude': -71.13043},
#    'transactions': ['delivery'],
#    'location': {'address1': '2 Corinth St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02131',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['2 Corinth St', 'Boston, MA 02131']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8351.563365327474},
#   {'id': 'G3CxSpcG9PKPtGQweVvtBw',
#    'alias': 'brueggers-bagels-boston-10',
#    'name': "Bruegger's Bagels",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TQVnm64Hv4z5LVySWxoPoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brueggers-bagels-boston-10?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 49,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.3546033, 'longitude': -71.0548548},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '211 Congress St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02110',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['211 Congress St', 'Boston, MA 02110']},
#    'phone': '+16174237105',
#    'display_phone': '(617) 423-7105',
#    'distance': 1542.4021973220053},
#   {'id': 'FsLAXnPaRbADLn35yK-Jjw',
#    'alias': 'honeycomb-cafe-boston',
#    'name': 'Honeycomb Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JSL8GSrIlTxHSbQQc6sIQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honeycomb-cafe-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 74,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.3115792502875,
#     'longitude': -71.0539349913597},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '107-109 Savin Hill Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02125',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['107-109 Savin Hill Ave', 'Boston, MA 02125']},
#    'phone': '+16172825400',
#    'display_phone': '(617) 282-5400',
#    'distance': 4275.863194701761},
#   {'id': '-JlTVATJAuCEFR0nxHRZXA',
#    'alias': 'bagels-best-needham',
#    'name': "Bagel's Best",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uP2omH4j9Lt8jKcVqOfUHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bagels-best-needham?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 70,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.2808481273969,
#     'longitude': -71.236970409125},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '113 Chapel St',
#     'address2': None,
#     'address3': '',
#     'city': 'Needham',
#     'zip_code': '02492',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['113 Chapel St', 'Needham, MA 02492']},
#    'phone': '+17814330003',
#    'display_phone': '(781) 433-0003',
#    'distance': 15530.051521592291},
#   {'id': '2m01uXA_2Wylogy_R8z9EA',
#    'alias': 'michaels-deli-brookline',
#    'name': "Michael's Deli",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tkNk7kWkVLWlJM6fZeAEjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/michaels-deli-brookline?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 456,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.3415984, 'longitude': -71.121215},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '256 Harvard St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brookline',
#     'zip_code': '02446',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['256 Harvard St', 'Brookline, MA 02446']},
#    'phone': '+16177383354',
#    'display_phone': '(617) 738-3354',
#    'distance': 4165.17171868176},
#   {'id': 'Hy4x9-6Hc5g9f8Uc4bqByQ',
#    'alias': 'brothers-and-sisters-co-coffeehouse-cafe-brookline',
#    'name': 'Brothers & Sisters Co Coffeehouse + Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hFGbEdAMLrMgGCW7RC9h0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brothers-and-sisters-co-coffeehouse-cafe-brookline?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 240,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.3327, 'longitude': -71.11803},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '7 Station St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brookline',
#     'zip_code': '02445',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['7 Station St', 'Brookline, MA 02445']},
#    'phone': '+16177305525',
#    'display_phone': '(617) 730-5525',
#    'distance': 4194.114006633357},
#   {'id': 'a8g7yBgZGH99u4WV6lJsgg',
#    'alias': 'boston-bagel-company-boston-2',
#    'name': 'Boston Bagel Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JeCfJcErZF9JGJ40Hk_XeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boston-bagel-company-boston-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 142,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 42.3355265, 'longitude': -71.0352539},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '753 E Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02127',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['753 E Broadway', 'Boston, MA 02127']},
#    'phone': '+18574964168',
#    'display_phone': '(857) 496-4168',
#    'distance': 3259.5253779100385},
#   {'id': 'i397Czl5dbPwrwFYrOLI5w',
#    'alias': 'boston-pocket-and-deli-boston',
#    'name': 'Boston Pocket & Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Jnt-1r7ust6ElUv_00LlCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boston-pocket-and-deli-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 15,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 42.3409690856934, 'longitude': -71.07666015625},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '682 Tremont St',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02118',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['682 Tremont St', 'Boston, MA 02118']},
#    'phone': '+16172660009',
#    'display_phone': '(617) 266-0009',
#    'distance': 881.9375691819642},
#   {'id': 'W6Xj0A9p_PU5kI5n2Ctqgw',
#    'alias': 'magnificent-muffin-and-bagel-shoppe-somerville',
#    'name': 'Magnificent Muffin & Bagel Shoppe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mZMUMzHKy6z4azc1Q9khCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magnificent-muffin-and-bagel-shoppe-somerville?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 157,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.4028991269781,
#     'longitude': -71.1266525229512},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1118 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Somerville',
#     'zip_code': '02144',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['1118 Broadway', 'Somerville, MA 02144']},
#    'phone': '+16176289000',
#    'display_phone': '(617) 628-9000',
#    'distance': 7628.68943316743},
#   {'id': 'VYM2c321AdMmpMI1DCRZIA',
#    'alias': 'solid-ground-cafe-boston',
#    'name': 'Solid Ground Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JGqzuVjTHmabpQ8rM4Rieg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/solid-ground-cafe-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 60,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 42.33367, 'longitude': -71.10544},
#    'transactions': ['delivery'],
#    'location': {'address1': '742 Huntington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Boston',
#     'zip_code': '02115',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['742 Huntington Ave', 'Boston, MA 02115']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3224.281692884604},
#   {'id': 'POgTNe-h22hzVBDg9it-mw',
#    'alias': 'berkeley-perk-cafe-boston',
#    'name': 'Berkeley Perk Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZH2s5D-7niC90UrMa9SaPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berkeley-perk-cafe-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 155,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.34679, 'longitude': -71.07061},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '69 Berkeley St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02116',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['69 Berkeley St', 'Boston, MA 02116']},
#    'phone': '+16174267375',
#    'display_phone': '(617) 426-7375',
#    'distance': 126.89716435424523},
#   {'id': '06feX4qEHFMcPZsiWtvYfw',
#    'alias': 'thinking-cup-boston-5',
#    'name': 'Thinking Cup',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QKyY2_3HLz5e2DkFBh9-fQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thinking-cup-boston-5?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 818,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.351734691006,
#     'longitude': -71.0746758944958},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '85 Newbury St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02116',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['85 Newbury St', 'Boston, MA 02116']},
#    'phone': '+16172473333',
#    'display_phone': '(617) 247-3333',
#    'distance': 516.6797579429581},
#   {'id': 'ZXWrd4x2HNz21jB_ds8v6g',
#    'alias': 'broadways-pastry-and-coffee-shop-boston',
#    'name': "Broadway's Pastry & Coffee Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UnERKvgDZWL89H96Nmz0SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/broadways-pastry-and-coffee-shop-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 62,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 42.33946, 'longitude': -71.05137},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '258 W Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02127',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['258 W Broadway', 'Boston, MA 02127']},
#    'phone': '+16172682253',
#    'display_phone': '(617) 268-2253',
#    'distance': 1876.2442630782589},
#   {'id': 'VTGCGDJZ_p2jJvH5xIvB6A',
#    'alias': 'blackbird-doughnuts-south-end-boston',
#    'name': 'Blackbird Doughnuts - South End',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/silRK7BzJl-pXIDIww9Uow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blackbird-doughnuts-south-end-boston?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 527,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 42.3455051631887,
#     'longitude': -71.0694191026184},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '492 Tremont St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02116',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['492 Tremont St', 'Boston, MA 02116']},
#    'phone': '+16174829000',
#    'display_phone': '(617) 482-9000',
#    'distance': 299.9598463962195},
#   {'id': '2Kq2vPsoNrQNVrfOIG6pbg',
#    'alias': 'cafe-beatrice-cambridge-2',
#    'name': 'Cafe Beatrice',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zt1SamqEiytS5FZtoivWHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-beatrice-cambridge-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 23,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 42.372156051994, 'longitude': -71.075838522921},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '100 N First St',
#     'address2': None,
#     'address3': '',
#     'city': 'Cambridge',
#     'zip_code': '02141',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['100 N First St', 'Cambridge, MA 02141']},
#    'phone': '+16179451349',
#    'display_phone': '(617) 945-1349',
#    'distance': 2719.701502412424},
#   {'id': 'e4r0wRKY_iNdmDffnV0ntw',
#    'alias': 'ogawa-coffee-boston-2',
#    'name': 'Ogawa Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KhV3KtvwBj3lCAndELFO8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ogawa-coffee-boston-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#    'review_count': 571,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 42.3568572843331,
#     'longitude': -71.0580796438568},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '10 Milk St',
#     'address2': '',
#     'address3': '',
#     'city': 'Boston',
#     'zip_code': '02108',
#     'country': 'US',
#     'state': 'MA',
#     'display_address': ['10 Milk St', 'Boston, MA 02108']},
#    'phone': '+16177807139',
#    'display_phone': '(617) 780-7139',
#    'distance': 1474.8203139964023}],
#  'total': 1100,
#  'region': {'center': {'longitude': -71.07124328613281,
#    'latitude': 42.34784169448538}}}

# %%
for key in bagels.keys():
    print(key)
# Out:
# businesses
# total
# region

# %%
bagels['businesses'][0]
# Out:
# {'id': 'ue0fG3vQkKpa9HheKVZFvA',
#  'alias': 'levend-bagelry-boston-2',
#  'name': 'Levend Bagelry',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0YTeRWCB7o1ELlgSwkXpXw/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/levend-bagelry-boston-2?adjust_creative=GCm8E-vatg1JVje_1SJkFA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GCm8E-vatg1JVje_1SJkFA',
#  'review_count': 94,
#  'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#   {'alias': 'bakeries', 'title': 'Bakeries'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 42.3619511, 'longitude': -71.057115},
#  'transactions': ['delivery'],
#  'price': '$',
#  'location': {'address1': '100 Hanover St',
#   'address2': '',
#   'address3': None,
#   'city': 'Boston',
#   'zip_code': '02108',
#   'country': 'US',
#   'state': 'MA',
#   'display_address': ['100 Hanover St', 'Boston, MA 02108']},
#  'phone': '+16179456123',
#  'display_phone': '(617) 945-6123',
#  'distance': 1964.3340646289942}

# %%
bagels['total']
# Out:
# 1100

# %%
bagels['region']
# Out:
# {'center': {'longitude': -71.07124328613281, 'latitude': 42.34784169448538}}

# %%
#makeing the bagels dictionary a dataframe
bagels_df = pd.DataFrame.from_dict(bagels['businesses'])

# %%
bagels_df.columns
# Out:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'coordinates', 'transactions', 'price',
#        'location', 'phone', 'display_phone', 'distance'],
#       dtype='object')

# %%
df = bagels_df.loc[:,['name', 'rating', 'review_count', 'price', 'location']]

# %%
df
# Out:
#                                          name  rating  review_count price  \
# 0                              Levend Bagelry     4.0            94     $
# 1                                 Bagelsaurus     4.0           648    $$
# 2                             Finagle A Bagel     3.5           154     $
# 3                           Katz Bagel Bakery     4.5           191     $
# 4                             Goldilox Bagels     4.5            73    $$
# 5                              Kupel's Bakery     3.5           417     $
# 6                               Exodus Bagels     4.5            42     $
# 7                     Rosenfeld Bagel Company     4.0           194     $
# 8                      Black Sheep Bagel Cafe     4.0           146     $
# 9                      Mamaleh's Delicatessen     4.0           452    $$
# 10  Davis Square Hand Crafted Donuts & Bagels     4.0           202     $
# 11                              Better Bagels     3.0            98    $$
# 12                                     Blunch     4.5           491     $
# 13                                    Turenne     4.5            16   NaN
# 14                       Pavement Coffeehouse     3.5           427     $
# 15                           Cafe Fresh Bagel     4.5           198     $
# 16                            One Mighty Mill     4.5            61     $
# 17                            Finagle A Bagel     3.0            71     $
# 18                     Archie's New York Deli     4.5           178     $
# 19                    Mike & Patty's - Boston     4.5          1778     $
# 20                          Bruegger's Bagels     3.5            64     $
# 21                              Render Coffee     4.5           502     $
# 22                       Pavement Coffeehouse     3.5           205     $
# 23                     Doughboy Donuts & Deli     4.0           178     $
# 24                               7ate9 Bakery     4.5            91    $$
# 25                       Revival Cafe+Kitchen     4.5             9   NaN
# 26                  Local 338 Bagels & Coffee     4.0            53     $
# 27                       Pavement Coffeehouse     4.0           144    $$
# 28                               Wicked Bagel     3.5           125     $
# 29                            The Bagel Table     3.5            56   NaN
# 30                       Einstein Bros Bagels     3.5             8     $
# 31                            The Bagel Table     3.5             6     $
# 32          Magnificent Muffin & Bagel Shoppe     4.5           121     $
# 33                      Broad Street Paulie's     4.5            16     $
# 34                            The Square Root     4.5            42   NaN
# 35                          Bruegger's Bagels     3.5            49     $
# 36                             Honeycomb Cafe     4.5            74     $
# 37                               Bagel's Best     4.0            70     $
# 38                             Michael's Deli     4.0           456    $$
# 39   Brothers & Sisters Co Coffeehouse + Cafe     4.0           240     $
# 40                       Boston Bagel Company     2.5           142     $
# 41                       Boston Pocket & Deli     5.0            15   NaN
# 42          Magnificent Muffin & Bagel Shoppe     4.0           157     $
# 43                          Solid Ground Cafe     5.0            60   NaN
# 44                         Berkeley Perk Cafe     4.0           155     $
# 45                               Thinking Cup     4.0           818    $$
# 46            Broadway's Pastry & Coffee Shop     4.5            62     $
# 47            Blackbird Doughnuts - South End     3.5           527    $$
# 48                              Cafe Beatrice     5.0            23   NaN
# 49                               Ogawa Coffee     4.0           571    $$
#
#                                              location
# 0   {'address1': '100 Hanover St', 'address2': '',...
# 1   {'address1': '1796 Massachusetts Ave', 'addres...
# 2   {'address1': '535 Boylston St', 'address2': ''...
# 3   {'address1': '139 Park St', 'address2': None, ...
# 4   {'address1': '186 Winthrop St', 'address2': ''...
# 5   {'address1': '421 Harvard St', 'address2': Non...
# 6   {'address1': '2 McCraw St', 'address2': None, ...
# 7   {'address1': '1280 Centre St', 'address2': '',...
# 8   {'address1': '56 John F Kennedy St', 'address2...
# 9   {'address1': '15 Hampshire St', 'address2': No...
# 10  {'address1': '377 Summer St', 'address2': '', ...
# 11  {'address1': '83A Seaport Blvd', 'address2': '...
# 12  {'address1': '59 E Springfield St', 'address2'...
# 13  {'address1': '251 Washington St', 'address2': ...
# 14  {'address1': '1096 Boylston St', 'address2': '...
# 15  {'address1': '896 Highland Ave', 'address2': N...
# 16  {'address1': '68 Exchange St', 'address2': Non...
# 17  {'address1': '277 Cambridge St', 'address2': '...
# 18  {'address1': '101 Arch St', 'address2': '', 'a...
# 19  {'address1': '12 Church St', 'address2': '', '...
# 20  {'address1': '375 Longwood Ave', 'address2': N...
# 21  {'address1': '563 Columbus Ave', 'address2': '...
# 22  {'address1': '286 Newbury St', 'address2': '',...
# 23  {'address1': '220 Dorchester Ave', 'address2':...
# 24  {'address1': '199C Highland Ave', 'address2': ...
# 25  {'address1': '103 Newbury St', 'address2': '',...
# 26  {'address1': '1727 Centre St', 'address2': '',...
# 27  {'address1': '1334 Boylston St', 'address2': '...
# 28  {'address1': '171 Massachusetts Ave', 'address...
# 29  {'address1': '9 Boylston St', 'address2': '', ...
# 30  {'address1': '725 Commonwealth Ave', 'address2...
# 31  {'address1': '86 Guest St', 'address2': '', 'a...
# 32  {'address1': '491 High St', 'address2': '', 'a...
# 33  {'address1': '64 Broad St', 'address2': '', 'a...
# 34  {'address1': '2 Corinth St', 'address2': '', '...
# 35  {'address1': '211 Congress St', 'address2': ''...
# 36  {'address1': '107-109 Savin Hill Ave', 'addres...
# 37  {'address1': '113 Chapel St', 'address2': None...
# 38  {'address1': '256 Harvard St', 'address2': Non...
# 39  {'address1': '7 Station St', 'address2': None,...
# 40  {'address1': '753 E Broadway', 'address2': '',...
# 41  {'address1': '682 Tremont St', 'address2': '',...
# 42  {'address1': '1118 Broadway', 'address2': None...
# 43  {'address1': '742 Huntington Ave', 'address2':...
# 44  {'address1': '69 Berkeley St', 'address2': '',...
# 45  {'address1': '85 Newbury St', 'address2': '', ...
# 46  {'address1': '258 W Broadway', 'address2': Non...
# 47  {'address1': '492 Tremont St', 'address2': '',...
# 48  {'address1': '100 N First St', 'address2': Non...
# 49  {'address1': '10 Milk St', 'address2': '', 'ad...

# %%
df = df.sort_values('rating', ascending = False)
df
# Out:
#                                          name  rating  review_count price  \
# 48                              Cafe Beatrice     5.0            23   NaN
# 43                          Solid Ground Cafe     5.0            60   NaN
# 41                       Boston Pocket & Deli     5.0            15   NaN
# 25                       Revival Cafe+Kitchen     4.5             9   NaN
# 15                           Cafe Fresh Bagel     4.5           198     $
# 33                      Broad Street Paulie's     4.5            16     $
# 24                               7ate9 Bakery     4.5            91    $$
# 34                            The Square Root     4.5            42   NaN
# 36                             Honeycomb Cafe     4.5            74     $
# 21                              Render Coffee     4.5           502     $
# 19                    Mike & Patty's - Boston     4.5          1778     $
# 18                     Archie's New York Deli     4.5           178     $
# 16                            One Mighty Mill     4.5            61     $
# 13                                    Turenne     4.5            16   NaN
# 12                                     Blunch     4.5           491     $
# 6                               Exodus Bagels     4.5            42     $
# 46            Broadway's Pastry & Coffee Shop     4.5            62     $
# 4                             Goldilox Bagels     4.5            73    $$
# 3                           Katz Bagel Bakery     4.5           191     $
# 32          Magnificent Muffin & Bagel Shoppe     4.5           121     $
# 39   Brothers & Sisters Co Coffeehouse + Cafe     4.0           240     $
# 27                       Pavement Coffeehouse     4.0           144    $$
# 38                             Michael's Deli     4.0           456    $$
# 42          Magnificent Muffin & Bagel Shoppe     4.0           157     $
# 44                         Berkeley Perk Cafe     4.0           155     $
# 37                               Bagel's Best     4.0            70     $
# 45                               Thinking Cup     4.0           818    $$
# 0                              Levend Bagelry     4.0            94     $
# 49                               Ogawa Coffee     4.0           571    $$
# 10  Davis Square Hand Crafted Donuts & Bagels     4.0           202     $
# 26                  Local 338 Bagels & Coffee     4.0            53     $
# 1                                 Bagelsaurus     4.0           648    $$
# 23                     Doughboy Donuts & Deli     4.0           178     $
# 7                     Rosenfeld Bagel Company     4.0           194     $
# 8                      Black Sheep Bagel Cafe     4.0           146     $
# 9                      Mamaleh's Delicatessen     4.0           452    $$
# 2                             Finagle A Bagel     3.5           154     $
# 47            Blackbird Doughnuts - South End     3.5           527    $$
# 5                              Kupel's Bakery     3.5           417     $
# 28                               Wicked Bagel     3.5           125     $
# 29                            The Bagel Table     3.5            56   NaN
# 20                          Bruegger's Bagels     3.5            64     $
# 22                       Pavement Coffeehouse     3.5           205     $
# 35                          Bruegger's Bagels     3.5            49     $
# 31                            The Bagel Table     3.5             6     $
# 30                       Einstein Bros Bagels     3.5             8     $
# 14                       Pavement Coffeehouse     3.5           427     $
# 11                              Better Bagels     3.0            98    $$
# 17                            Finagle A Bagel     3.0            71     $
# 40                       Boston Bagel Company     2.5           142     $
#
#                                              location
# 48  {'address1': '100 N First St', 'address2': Non...
# 43  {'address1': '742 Huntington Ave', 'address2':...
# 41  {'address1': '682 Tremont St', 'address2': '',...
# 25  {'address1': '103 Newbury St', 'address2': '',...
# 15  {'address1': '896 Highland Ave', 'address2': N...
# 33  {'address1': '64 Broad St', 'address2': '', 'a...
# 24  {'address1': '199C Highland Ave', 'address2': ...
# 34  {'address1': '2 Corinth St', 'address2': '', '...
# 36  {'address1': '107-109 Savin Hill Ave', 'addres...
# 21  {'address1': '563 Columbus Ave', 'address2': '...
# 19  {'address1': '12 Church St', 'address2': '', '...
# 18  {'address1': '101 Arch St', 'address2': '', 'a...
# 16  {'address1': '68 Exchange St', 'address2': Non...
# 13  {'address1': '251 Washington St', 'address2': ...
# 12  {'address1': '59 E Springfield St', 'address2'...
# 6   {'address1': '2 McCraw St', 'address2': None, ...
# 46  {'address1': '258 W Broadway', 'address2': Non...
# 4   {'address1': '186 Winthrop St', 'address2': ''...
# 3   {'address1': '139 Park St', 'address2': None, ...
# 32  {'address1': '491 High St', 'address2': '', 'a...
# 39  {'address1': '7 Station St', 'address2': None,...
# 27  {'address1': '1334 Boylston St', 'address2': '...
# 38  {'address1': '256 Harvard St', 'address2': Non...
# 42  {'address1': '1118 Broadway', 'address2': None...
# 44  {'address1': '69 Berkeley St', 'address2': '',...
# 37  {'address1': '113 Chapel St', 'address2': None...
# 45  {'address1': '85 Newbury St', 'address2': '', ...
# 0   {'address1': '100 Hanover St', 'address2': '',...
# 49  {'address1': '10 Milk St', 'address2': '', 'ad...
# 10  {'address1': '377 Summer St', 'address2': '', ...
# 26  {'address1': '1727 Centre St', 'address2': '',...
# 1   {'address1': '1796 Massachusetts Ave', 'addres...
# 23  {'address1': '220 Dorchester Ave', 'address2':...
# 7   {'address1': '1280 Centre St', 'address2': '',...
# 8   {'address1': '56 John F Kennedy St', 'address2...
# 9   {'address1': '15 Hampshire St', 'address2': No...
# 2   {'address1': '535 Boylston St', 'address2': ''...
# 47  {'address1': '492 Tremont St', 'address2': '',...
# 5   {'address1': '421 Harvard St', 'address2': Non...
# 28  {'address1': '171 Massachusetts Ave', 'address...
# 29  {'address1': '9 Boylston St', 'address2': '', ...
# 20  {'address1': '375 Longwood Ave', 'address2': N...
# 22  {'address1': '286 Newbury St', 'address2': '',...
# 35  {'address1': '211 Congress St', 'address2': ''...
# 31  {'address1': '86 Guest St', 'address2': '', 'a...
# 30  {'address1': '725 Commonwealth Ave', 'address2...
# 14  {'address1': '1096 Boylston St', 'address2': '...
# 11  {'address1': '83A Seaport Blvd', 'address2': '...
# 17  {'address1': '277 Cambridge St', 'address2': '...
# 40  {'address1': '753 E Broadway', 'address2': '',...

# %%
fig, ax = plt.subplots(figsize = (15,7.5))
x = df['name'][:25]
y = df['rating'][:25]
ax.set_xlabel('Name', fontsize = 17)
ax.set_ylabel('Rating', fontsize = 17)
ax.set_title('Bagel Places Boston', fontsize = 24)
plt.xticks(rotation=80, fontsize = 15)
ax.bar(x,y, color = 'dodgerblue')

plt.savefig('Bagels_namerating')
