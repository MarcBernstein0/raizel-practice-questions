# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/BACHelorette_.csv')

# %%
df
# Out:
#              SHOW  SEASON     CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 0            SHOW  SEASON             ID             1             2
# 1    Bachelorette      13     13_BRYAN_A            R1           NaN
# 2    Bachelorette      13     13_PETER_K           NaN             R
# 3    Bachelorette      13      13_ERIC_B           NaN           NaN
# 4    Bachelorette      13      13_DEAN_U           NaN             R
# ..            ...     ...            ...           ...           ...
# 916      Bachelor      01  01_KRISTINA_X             E           NaN
# 917      Bachelor      01      01_LISA_X             E           NaN
# 918      Bachelor      01     01_PAULA_X             E           NaN
# 919      Bachelor      01    01_RACHEL_X             E           NaN
# 920      Bachelor      01     01_WENDI_X             E           NaN
#
#     ELIMINATION-3 ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  \
# ...

# %%
df[df['ELIMINATION-1'] == 'E']
# Out:
#              SHOW SEASON     CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 24   Bachelorette     13     13_BLAKE_K             E           NaN
# 25   Bachelorette     13     13_GRANT_H             E           NaN
# 26   Bachelorette     13  13_JEDIDIAH_B             E           NaN
# 27   Bachelorette     13      13_KYLE_S             E           NaN
# 28   Bachelorette     13   13_MICHAEL_B             E           NaN
# ..            ...    ...            ...           ...           ...
# 916      Bachelor     01  01_KRISTINA_X             E           NaN
# 917      Bachelor     01      01_LISA_X             E           NaN
# 918      Bachelor     01     01_PAULA_X             E           NaN
# 919      Bachelor     01    01_RACHEL_X             E           NaN
# 920      Bachelor     01     01_WENDI_X             E           NaN
#
#     ELIMINATION-3 ELIMINATION-4 ELIMINATION-5 ELIMINATION-6 ELIMINATION-7  \
# 24            NaN           NaN           NaN           NaN           NaN
# ...

# %%
df[df['ELIMINATION-7'] == 'E']
# Out:
#              SHOW SEASON      CONTESTANT ELIMINATION-1 ELIMINATION-2  \
# 37   Bachelorette     12      12_JAMES_T           NaN             R
# 63   Bachelorette     11      11_JARED_H           NaN           NaN
# 91   Bachelorette     10      10_BRIAN_O           NaN           NaN
# 92   Bachelorette     10      10_DYLAN_P           NaN           NaN
# 117  Bachelorette     09    09_MICHAEL_G            R1           NaN
# 143  Bachelorette     08       08_JOHN_W           NaN           NaN
# 169  Bachelorette     07      07_LUCAS_D           NaN           NaN
# 195  Bachelorette     06         06_TY_B           NaN             R
# 221  Bachelorette     05      05_JESSE_K           NaN           NaN
# 222  Bachelorette     05    05_MICHAEL_S           NaN           NaN
# 250  Bachelorette     04     04_JEREMY_A            R1             R
# 275  Bachelorette     03  03_JOHN PAUL_M           NaN           NaN
# 301  Bachelorette     02    02_MATTHEW_H           NaN           NaN
# ...

# %%
corona = pd.read_csv('../data/usa_county_wise.csv')

# %%
corona
# Out:
#              UID iso2 iso3  code3     FIPS          Admin2  \
# 0             16   AS  ASM     16     60.0             NaN
# 1            316   GU  GUM    316     66.0             NaN
# 2            580   MP  MNP    580     69.0             NaN
# 3       63072001   PR  PRI    630  72001.0        Adjuntas
# 4       63072003   PR  PRI    630  72003.0          Aguada
# ...          ...  ...  ...    ...      ...             ...
# 627915  84070016   US  USA    840      NaN    Central Utah
# 627916  84070017   US  USA    840      NaN  Southeast Utah
# 627917  84070018   US  USA    840      NaN  Southwest Utah
# 627918  84070019   US  USA    840      NaN       TriCounty
# 627919  84070020   US  USA    840      NaN    Weber-Morgan
#
#                   Province_State Country_Region        Lat       Long_  \
# 0                 American Samoa             US -14.271000 -170.132000
# 1                           Guam             US  13.444300  144.793700
# ...

# %%
corona[corona['Province_State'] == 'New Jersey']
# Out:
#              UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 1856    84034001   US  USA    840  34001.0    Atlantic     New Jersey
# 1857    84034003   US  USA    840  34003.0      Bergen     New Jersey
# 1858    84034005   US  USA    840  34005.0  Burlington     New Jersey
# 1859    84034007   US  USA    840  34007.0      Camden     New Jersey
# 1860    84034009   US  USA    840  34009.0    Cape May     New Jersey
# ...          ...  ...  ...    ...      ...         ...            ...
# 626454  84034037   US  USA    840  34037.0      Sussex     New Jersey
# 626455  84034039   US  USA    840  34039.0       Union     New Jersey
# 626456  84034041   US  USA    840  34041.0      Warren     New Jersey
# 627834  84080034   US  USA    840  80034.0   Out of NJ     New Jersey
# 627887  84090034   US  USA    840  90034.0  Unassigned     New Jersey
#
#        Country_Region        Lat      Long_                Combined_Key  \
# ...

# %%
covid = pd.read_csv('../data/COVID-19_Case_Surveillance.csv')

# %%
covid
# Out:
#        cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# 0         2020/03/22  2020/03/15  2020/03/11  Laboratory-confirmed case
# 1         2020/03/23  2020/03/15         NaN  Laboratory-confirmed case
# 2         2020/03/15  2020/03/15         NaN  Laboratory-confirmed case
# 3         2020/03/15  2020/03/15         NaN  Laboratory-confirmed case
# 4         2020/03/15  2020/03/15         NaN  Laboratory-confirmed case
# ...              ...         ...         ...                        ...
# 978020    2020/07/02         NaN         NaN  Laboratory-confirmed case
# 978021    2020/07/09         NaN         NaN  Laboratory-confirmed case
# 978022    2020/08/19         NaN         NaN  Laboratory-confirmed case
# 978023    2020/08/30         NaN  2020/08/30  Laboratory-confirmed case
# 978024    2020/06/29         NaN      2020/0                        NaN
#
#             sex      age_group Race and ethnicity (combined)  hosp_yn  \
# ...

# %%
corona[(corona['Province_State'] == 'New Jersey') & (corona['Date'] == '7/27/20') ]
# Out:
#              UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 626436  84034001   US  USA    840  34001.0    Atlantic     New Jersey
# 626437  84034003   US  USA    840  34003.0      Bergen     New Jersey
# 626438  84034005   US  USA    840  34005.0  Burlington     New Jersey
# 626439  84034007   US  USA    840  34007.0      Camden     New Jersey
# 626440  84034009   US  USA    840  34009.0    Cape May     New Jersey
# 626441  84034011   US  USA    840  34011.0  Cumberland     New Jersey
# 626442  84034013   US  USA    840  34013.0       Essex     New Jersey
# 626443  84034015   US  USA    840  34015.0  Gloucester     New Jersey
# 626444  84034017   US  USA    840  34017.0      Hudson     New Jersey
# 626445  84034019   US  USA    840  34019.0   Hunterdon     New Jersey
# 626446  84034021   US  USA    840  34021.0      Mercer     New Jersey
# 626447  84034023   US  USA    840  34023.0   Middlesex     New Jersey
# ...
