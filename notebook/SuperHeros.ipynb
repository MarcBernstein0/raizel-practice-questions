# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_rows = 999
pd.options.display.max_columns= None
pd.get_option('display.max_colwidth', 400)
pd.set_option('display.float_format',  '{:,.2}'.format)

# %%
hero = pd.read_excel('../data/super_hero_powers.xlsx')
super_hero = pd.read_excel('../data/super_heroes_information.xlsx')

# %%
# hero.head()

# %%
hero = hero.rename(columns={'hero_names': 'name'})

# %%
# super_hero.head()

# %%
super_hero = super_hero.drop('Unnamed: 0', axis=1)

# %%
super_hero.shape
# hero.shape
# Out:
# (734, 10)

# %%
combined_hero = pd.merge(hero, super_hero, on = 'name', how='outer')

# %%
combined_hero.head()
# Out:
#           name Agility Accelerated Healing Lantern Power Ring  \
# 0      3-D Man    True               False              False
# 1       A-Bomb   False                True              False
# 2   Abe Sapien    True                True              False
# 3     Abin Sur   False               False               True
# 4  Abomination   False                True              False
#
#   Dimensional Awareness Cold Resistance Durability Stealth Energy Absorption  \
# 0                 False           False      False   False             False
# 1                 False           False       True   False             False
# 2                 False            True       True   False             False
# 3                 False           False      False   False             False
# 4                 False           False      False   False             False
#
#   Flight Danger Sense Underwater breathing Marksmanship Weapons Master  \
# ...

# %%
combined_hero.shape
# Out:
# (758, 177)

# %%
#gets all column names
pd.options.display.max_seq_items = None

# %%
combined_hero.columns
# Out:
# Index(['name', 'Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight', 'Danger Sense', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Power Augmentation',
#        'Animal Attributes', 'Longevity', 'Intelligence', 'Super Strength',
#        'Cryokinesis', 'Telepathy', 'Energy Armor', 'Energy Blasts',
#        'Duplication', 'Size Changing', 'Density Control', 'Stamina',
#        'Astral Travel', 'Audio Control', 'Dexterity', 'Omnitrix',
#        'Super Speed', 'Possession', 'Animal Oriented Powers',
#        'Weapon-based Powers', 'Electrokinesis', 'Darkforce Manipulation',
#        'Death Touch', 'Teleportation', 'Enhanced Senses', 'Telekinesis',
#        'Energy Beams', 'Magic', 'Hyperkinesis', 'Jump', 'Clairvoyance',
#        'Dimensional Travel', 'Power Sense', 'Shapeshifting',
# ...

# %%
# combined_hero[combined_hero[('Accelerated Healing')] == True]
#               | combined_hero[('Time Manipulation')] == True]

# %%
combined_hero[combined_hero['name'] == 'Dr Manhattan']
# Out:
#              name Agility Accelerated Healing Lantern Power Ring  \
# 218  Dr Manhattan   False                True              False
#
#     Dimensional Awareness Cold Resistance Durability Stealth  \
# 218                 False           False       True   False
#
#     Energy Absorption Flight Danger Sense Underwater breathing Marksmanship  \
# 218              True   True        False                False        False
#
#     Weapons Master Power Augmentation Animal Attributes Longevity  \
# 218          False              False             False      True
#
#     Intelligence Super Strength Cryokinesis Telepathy Energy Armor  \
# 218         True           True       False     False        False
#
#     Energy Blasts Duplication Size Changing Density Control Stamina  \
# 218          True        True          True            True   False
#
#     Astral Travel Audio Control Dexterity Omnitrix Super Speed Possession  \
# ...

# %%
# super_power_lst = combined_hero.columns.to_list()

# %%
# super_power_lst

# %%
combined_hero[combined_hero['Thirstokinesis'] == True]
# Out:
#              name Agility Accelerated Healing Lantern Power Ring  \
# 361  Kool-Aid Man   False               False              False
#
#     Dimensional Awareness Cold Resistance Durability Stealth  \
# 361                 False           False       True   False
#
#     Energy Absorption Flight Danger Sense Underwater breathing Marksmanship  \
# 361             False  False        False                False        False
#
#     Weapons Master Power Augmentation Animal Attributes Longevity  \
# 361          False              False             False     False
#
#     Intelligence Super Strength Cryokinesis Telepathy Energy Armor  \
# 361        False          False       False     False        False
#
#     Energy Blasts Duplication Size Changing Density Control Stamina  \
# 361         False       False         False           False   False
#
#     Astral Travel Audio Control Dexterity Omnitrix Super Speed Possession  \
# ...

# %%
# super_hero['Weight'].astype(int)

# %%
# super_hero[super_hero['Gender'] == 'Female']

# %%
Thirstokinesis = combined_hero[combined_hero['Thirstokinesis'] == True]['name']
Accelerated_Healing = combined_hero[combined_hero[('Accelerated Healing')] == True]['name']
Underwater_Breathing = combined_hero[combined_hero[('Underwater breathing')] == True]['name']

# %%
Thirstokinesis
# Out:
# 361    Kool-Aid Man
# Name: name, dtype: object

# %%
fig, ax = plt.subplots(figsize = (15,4))
# x = [Thirstokinesis, Accelerated_Healing, Underwater_Breathing]
x = ['Thirstokinesis', 'Underwater_Breathing']
y =[len(Thirstokinesis), len(Underwater_Breathing)] 
ax.set_xlabel('Name', fontsize = 17)
ax.set_ylabel('Number of Heros', fontsize = 17)
ax.set_title('Super Powers', fontsize = 24)
plt.xticks(rotation=80, fontsize = 15)
plt.yticks(fontsize=15)
ax.bar(x,y, color = 'dodgerblue')
# ax.set(facecolor = "white")
# Out:
# <BarContainer object of 2 artists>

# %%
combined_hero.pivot(index=)

# %%
combined_hero.stack()
# Out:
# 0    name                           3-D Man
#      Agility                           True
#      Accelerated Healing              False
#      Lantern Power Ring               False
#      Dimensional Awareness            False
#                                   ...
# 757  Height                         1.9e+02
#      Publisher                Marvel Comics
#      Skin color                           -
#      Alignment                          bad
#      Weight                         9.5e+01
# Length: 121575, dtype: object

# %%
combined_hero.unstack()
# Out:
# name    0          3-D Man
#         1           A-Bomb
#         2       Abe Sapien
#         3         Abin Sur
#         4      Abomination
#                   ...
# Weight  753        6.5e+01
#         754        3.9e+01
#         755       -9.9e+01
#         756        1.2e+02
#         757        9.5e+01
# Length: 134166, dtype: object

# %%
combined_hero.groupby(['name', 'Agility', 'Accelerated Healing', 'Lantern Power Ring',
       'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
       'Energy Absorption', 'Flight', 'Danger Sense', 'Underwater breathing',
       'Marksmanship', 'Weapons Master', 'Power Augmentation',
       'Animal Attributes', 'Longevity', 'Intelligence', 'Super Strength',
       'Cryokinesis', 'Telepathy', 'Energy Armor', 'Energy Blasts',
       'Duplication', 'Size Changing', 'Density Control', 'Stamina',
       'Astral Travel', 'Audio Control', 'Dexterity', 'Omnitrix',
       'Super Speed', 'Possession', 'Animal Oriented Powers',
       'Weapon-based Powers', 'Electrokinesis', 'Darkforce Manipulation',
       'Death Touch', 'Teleportation', 'Enhanced Senses', 'Telekinesis',
       'Energy Beams', 'Magic', 'Hyperkinesis', 'Jump', 'Clairvoyance',
       'Dimensional Travel', 'Power Sense', 'Shapeshifting',
       'Peak Human Condition', 'Immortality', 'Camouflage', 'Element Control',
       'Phasing', 'Astral Projection', 'Electrical Transport', 'Fire Control',
       'Projection', 'Summoning', 'Enhanced Memory', 'Reflexes',
       'Invulnerability', 'Energy Constructs', 'Force Fields',
       'Self-Sustenance', 'Anti-Gravity', 'Empathy', 'Power Nullifier',
       'Radiation Control', 'Psionic Powers', 'Elasticity',
       'Substance Secretion', 'Elemental Transmogrification',
       'Technopath/Cyberpath', 'Photographic Reflexes', 'Seismic Power',
       'Animation', 'Precognition', 'Mind Control', 'Fire Resistance',
       'Power Absorption', 'Enhanced Hearing', 'Nova Force', 'Insanity',
       'Hypnokinesis', 'Animal Control', 'Natural Armor', 'Intangibility',
       'Enhanced Sight', 'Molecular Manipulation', 'Heat Generation',
       'Adaptation', 'Gliding', 'Power Suit', 'Mind Blast',
       'Probability Manipulation', 'Gravity Control', 'Regeneration',
       'Light Control', 'Echolocation', 'Levitation',
       'Toxin and Disease Control', 'Banish', 'Energy Manipulation',
       'Heat Resistance', 'Natural Weapons', 'Time Travel', 'Enhanced Smell',
       'Illusions', 'Thirstokinesis', 'Hair Manipulation', 'Illumination',
       'Omnipotent', 'Cloaking', 'Changing Armor', 'Power Cosmic',
       'Biokinesis', 'Water Control', 'Radiation Immunity',
       'Vision - Telescopic', 'Toxin and Disease Resistance',
       'Spatial Awareness', 'Energy Resistance', 'Telepathy Resistance',
       'Molecular Combustion', 'Omnilingualism', 'Portal Creation',
       'Magnetism', 'Mind Control Resistance', 'Plant Control', 'Sonar',
       'Sonic Scream', 'Time Manipulation', 'Enhanced Touch',
       'Magic Resistance', 'Invisibility', 'Sub-Mariner',
       'Radiation Absorption', 'Intuitive aptitude', 'Vision - Microscopic',
       'Melting', 'Wind Control', 'Super Breath', 'Wallcrawling',
       'Vision - Night', 'Vision - Infrared', 'Grim Reaping',
       'Matter Absorption', 'The Force', 'Resurrection', 'Terrakinesis',
       'Vision - Heat', 'Vitakinesis', 'Radar Sense', 'Qwardian Power Ring',
       'Weather Control', 'Vision - X-Ray', 'Vision - Thermal', 'Web Creation',
       'Reality Warping', 'Odin Force', 'Symbiote Costume', 'Speed Force',
       'Phoenix Force', 'Molecular Dissipation', 'Vision - Cryo',
       'Omnipresent', 'Omniscient', 'Gender', 'Eye color', 'Race',
       'Hair color', 'Height', 'Publisher', 'Skin color', 'Alignment',
       'Weight']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...
