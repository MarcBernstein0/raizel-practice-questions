# %%
import pandas as pd

pd.options.display.max_rows = 999
pd.options.display.max_columns= 999
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.float_format',  '{:,.2}'.format)
# Out:
# <ipython-input-1-f14289167729>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# https://domohelp.domo.com/hc/en-us/articles/360043931814-Fun-Sample-DataSets

# %%
jeopardy = pd.read_excel('../data/JEOPARDY.xlsx')

# %%
jeopardy.head()
# Out:
#    Show Number   Air Date      Round                         Category  Value  \
# 0  4680        2004-12-31  Jeopardy!  HISTORY                          200
# 1  4680        2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  200
# 2  4680        2004-12-31  Jeopardy!  EVERYBODY TALKS ABOUT IT...      200
# 3  4680        2004-12-31  Jeopardy!  THE COMPANY LINE                 200
# 4  4680        2004-12-31  Jeopardy!  EPITAPHS & TRIBUTES              200
#
#                                                                                                       Question  \
# 0  For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2  The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3  In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4  Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
#
#        Answer
# 0  Copernicus
# 1  Jim Thorpe
# 2  Arizona
# 3  McDonald's
# 4  John Adams

# %%
show_1 = jeopardy[jeopardy['Show Number'] == 1]

# %%
type(show_1)
# Out:
# pandas.core.frame.DataFrame

# %%
show_1.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
show_1 = show_1.rename(columns={' Question':'Question', ' Air Date':'Date Aired', ' Category':'Category', 
                                ' Value':'Value', ' Answer':'Answer'})

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-8-0891b765a168>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# show_1[['Question', 'Answer']]

# %%
# show_1.loc[:,['Question', 'Answer']]

# %%
jeopardy = jeopardy.rename(columns={' Question':'Question', ' Air Date':'Date Aired', ' Category':'Category', 
                                ' Value':'Value', ' Answer':'Answer'})

# %%
jeopardy[1840:1801:-1]
# Out:
#       Show Number   Air Date             Round                    Category  \
# 1840  3113        1998-02-25  Double Jeopardy!  TAKE A GUESS
# 1839  3113        1998-02-25  Double Jeopardy!  IT'S GREEK MYTHOLOGY TO ME
# 1838  3113        1998-02-25  Double Jeopardy!  CROSSWORD CLUES "M"
# 1837  3113        1998-02-25  Double Jeopardy!  ACTRESSES
# 1836  3113        1998-02-25  Double Jeopardy!  THE MAINE ATTRACTION
# 1835  3113        1998-02-25  Double Jeopardy!  LITERARY HOUSES
# 1834  3113        1998-02-25  Double Jeopardy!  TAKE A GUESS
# 1833  3113        1998-02-25  Double Jeopardy!  IT'S GREEK MYTHOLOGY TO ME
# 1832  3113        1998-02-25  Double Jeopardy!  CROSSWORD CLUES "M"
# 1831  3113        1998-02-25  Double Jeopardy!  ACTRESSES
# 1830  3113        1998-02-25  Double Jeopardy!  THE MAINE ATTRACTION
# 1829  3113        1998-02-25  Double Jeopardy!  LITERARY HOUSES
# 1828  3113        1998-02-25  Double Jeopardy!  TAKE A GUESS
# 1827  3113        1998-02-25  Double Jeopardy!  IT'S GREEK MYTHOLOGY TO ME
# 1826  3113        1998-02-25  Double Jeopardy!  CROSSWORD CLUES "M"
# 1825  3113        1998-02-25  Double Jeopardy!  ACTRESSES
# 1824  3113        1998-02-25  Double Jeopardy!  THE MAINE ATTRACTION
# 1823  3113        1998-02-25  Double Jeopardy!  LITERARY HOUSES
# 1822  3113        1998-02-25  Jeopardy!         WHAT'CHA GOT COOKIN'?
# 1821  3113        1998-02-25  Jeopardy!         HEY, GOOD-LOOKIN'
# 1820  3113        1998-02-25  Jeopardy!         AT THE BUILDING SITE
# 1819  3113        1998-02-25  Jeopardy!         ROCK MUSIC
# 1818  3113        1998-02-25  Jeopardy!         SIMPLE SCIENCE
# 1817  3113        1998-02-25  Jeopardy!         COMMON BONDS
# 1820  A teacher could handle this, the moving of earth to form a smooth surface for a roadway
# 1819  He recorded his 1982 hit album, "Nebraska", as a series of demos on a 4-track machine at home
# 1818  French mathematician who devised the plotting system that uses coordinates named for him
# 1817  Purpose of the structures seen here: <a href="http://www.j-archive.com/media/1998-02-25_J_25.jpg" target="_blank">[1]</a> <a href="http://www.j-archive.com/media/1998-02-25_J_25a.jpg" target="_blank">[2]</a> <a href="http://www.j-archive.com/media/1998-02-25_J_25b.jpg" target="_blank">[3]</a>
# 1816  I'm sauteeing this organ meat in butter & lemon juice, as you'd know, if you had any
# 1815  Psalm 8 declares, "Out of the mouth of" these "and sucklings hast thou ordained strength"
# 1814  He'll get you stoned or brickworked, & maybe even teach you a secret handshake
# 1813  This Seattle grunge band backed Neil Young on his "Mirror Ball" CD
# 1812  A poison in pure form, this element used as a germicide on cuts has a chemical symbol that's a pronoun
# 1811  Roofs, halos, quantum mechanics
# 1810  I'm making passover breakfast fun by using this unleavened bread in a version of French toast
# 1809  In boxing, it's when you've fallen & you can't get up
# 1808  A Fats Waller is a pianist & this "waller" is an installer of plasterboard
# 1807  (<a href="http://www.j-archive.com/media/1998-02-25_J_04.jpg" target="_blank">Hi.  I am Chris Hardwick.</a>)  In April 1987 MTV premiered the video show "Headbanger's Ball" for devotees of this type of music
# 1806  We wouldn't fib, your fibula runs parallel with this bone
# 1805  Shirt, kite, donkey
# 1804  Don't be intimidated by the skewers; I'll use them on the marinated lamb to make this
# 1803  In a 1979 film, Dudley Moore gives her a rating of 11 on a scale of 1-10
# 1802  The current affairs this person deals with are labelled H & C
#
#                             Answer
# 1840  a dense winter fog
# 1839  Ares
# 1838  March
# 1837  Liz Taylor
# 1836  blueberries
# 1835  Willa Cather
# 1834  rocking (or swinging)
# 1833  Zeus
# 1832  mantis
# 1831  Lindsey Crouse
# 1830  (George Herbert Walker) Bush
# 1829  The Accidental Tourist
# 1828  William
# 1827  Helen
# 1826  mine
# 1825  Elisabeth Shue
# 1824  Augusta
# 1823  (John) Updike
# 1822  a consomm̩
# 1821  a bombshell
# 1820  a grader
# 1819  Bruce Springsteen
# 1818  Rene Descartes
# 1817  astronomy (or observatories)
# 1816  brains
# 1815  babes
# 1814  a mason
# 1813  Pearl Jam
# 1812  iodine
# 1811  things that are over my head
# 1810  matzah
# 1809  a knockout
# 1808  a drywaller
# 1807  heavy metal
# 1806  your tibia
# 1805  (things with) tails
# 1804  shish kabob
# 1803  Bo Derek
# 1802  the plumber

# %%
jeopardy['Question'].isna().sum()
# Out:
# 2

# %%
jeopardy = jeopardy.dropna(subset=['Question'])

# %%
jeopardy.isna().sum()
# Out:
# Show Number    0
# Date Aired     0
#  Round         0
# Category       152
# Value          0
# Question       0
# Answer         34
# dtype: int64

# %%
jeopardy.dtypes
# Out:
# Show Number    int64
# Date Aired     datetime64[ns]
#  Round         object
# Category       object
# Value          object
# Question       object
# Answer         object
# dtype: object

# %%
jeopardy = jeopardy.dropna()

# %%
#needs == True - idk why
jeopardy[jeopardy['Question'].str.contains('covid', case=False)  == True]
# Out:
# Empty DataFrame
# Columns: [Show Number, Date Aired,  Round, Category, Value, Question, Answer]
# Index: []
