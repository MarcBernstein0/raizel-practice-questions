# %%
import pandas as pd

pd.options.display.max_rows = 999
pd.options.display.max_columns= 999
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.float_format',  '{:,.2}'.format)
# Out:
# <ipython-input-1-f14289167729>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# https://domohelp.domo.com/hc/en-us/articles/360043931814-Fun-Sample-DataSets

# %%
jeopardy = pd.read_excel('../data/JEOPARDY.xlsx')

# %%
jeopardy.head()
# Out:
#    Show Number   Air Date      Round                         Category  Value  \
# 0  4680        2004-12-31  Jeopardy!  HISTORY                          200
# 1  4680        2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  200
# 2  4680        2004-12-31  Jeopardy!  EVERYBODY TALKS ABOUT IT...      200
# 3  4680        2004-12-31  Jeopardy!  THE COMPANY LINE                 200
# 4  4680        2004-12-31  Jeopardy!  EPITAPHS & TRIBUTES              200
#
#                                                                                                       Question  \
# 0  For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2  The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3  In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4  Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
#
#        Answer
# 0  Copernicus
# 1  Jim Thorpe
# 2  Arizona
# 3  McDonald's
# 4  John Adams

# %%
show_1 = jeopardy[jeopardy['Show Number'] == 1]

# %%
type(show_1)
# Out:
# pandas.core.frame.DataFrame

# %%
show_1.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
show_1 = show_1.rename(columns={' Question':'Question', ' Air Date':'Date Aired', ' Category':'Category', 
                                ' Value':'Value', ' Answer':'Answer'})

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-8-0891b765a168>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# show_1[['Question', 'Answer']]

# %%
# show_1.loc[:,['Question', 'Answer']]

# %%
jeopardy[1200:1191:-1]
# Out:
#       Show Number   Air Date      Round                Category  Value  \
# 1200  1302        1990-04-10  Jeopardy!  ADVERTISING SLOGANS     300
# 1199  1302        1990-04-10  Jeopardy!  FAMOUS NAMES            300
# 1198  1302        1990-04-10  Jeopardy!  PRESIDENTIAL ASTROLOGY  200
# 1197  1302        1990-04-10  Jeopardy!  4-LETTER WORDS          200
# 1196  1302        1990-04-10  Jeopardy!  WEATHER                 200
# 1195  1302        1990-04-10  Jeopardy!  THE BIBLE               200
# 1194  1302        1990-04-10  Jeopardy!  ADVERTISING SLOGANS     200
# 1193  1302        1990-04-10  Jeopardy!  FAMOUS NAMES            200
# 1192  1302        1990-04-10  Jeopardy!  PRESIDENTIAL ASTROLOGY  100
#
#                                                                                        Question  \
# 1200  "I like" this lemon-lime soda "in you"
# 1199  "The First Time Ever" she had a No. 1 album was "First Take" in 1972
# 1198  It's Jimmy Carter's sign, so don't tip his scales
# 1197  From the Greek word for "deep sleep", it's a deep, prolonged unconsciousness
# 1196  Air is described as supersaturated when the relative humidity is higher than this percent
# 1195  I Corinthians 7:9 states, "It is better to marry than to" do this
# 1194  "Wouldn't you really rather have" one of these cars
# 1193  Creator of "The Cisco Kid", William Sidney Porter was better known by this name
# 1192  Gerald Ford was the last president born under this "crab"by sign
#
#              Answer
# 1200  Sprite
# 1199  Roberta Flack
# 1198  Libra
# 1197  Coma
# 1196  1
# 1195  Burn
# 1194  Buick
# 1193  O. Henry
# 1192  Cancer

# %%
jeopardy[' Question'].isna().sum()
# Out:
# 2

# %%
jeopardy = jeopardy.dropna(subset=[' Question'])

# %%
jeopardy.isna().sum()
# Out:
# Show Number    0
#  Air Date      0
#  Round         0
#  Category      152
#  Value         0
#  Question      0
#  Answer        34
# dtype: int64

# %%
jeopardy.dtypes
# Out:
# Show Number    int64
#  Air Date      datetime64[ns]
#  Round         object
#  Category      object
#  Value         object
#  Question      object
#  Answer        object
# dtype: object

# %%
jeopardy = jeopardy.dropna()

# %%
#needs == True - idk why
jeopardy[jeopardy[' Question'].str.contains('scuba', case=False)  == True]
# Out:
#         Show Number   Air Date             Round  \
# 8563    62          1984-12-04  Jeopardy!
# 16055   5001        2006-05-15  Jeopardy!
# 17432   2969        1997-06-26  Jeopardy!
# 32512   4140        2002-09-06  Double Jeopardy!
# 36455   4218        2002-12-25  Jeopardy!
# 43698   6078        2011-02-02  Jeopardy!
# 45878   4648        2004-11-17  Double Jeopardy!
# 47130   3287        1998-12-15  Jeopardy!
# 71421   5235        2007-05-18  Jeopardy!
# 82397   4755        2005-04-15  Double Jeopardy!
# 87030   5267        2007-07-03  Jeopardy!
# 88981   3029        1997-10-30  Double Jeopardy!
# 89715   5390        2008-02-01  Double Jeopardy!
# 122020  5068        2006-09-27  Double Jeopardy!
# 126257  6080        2011-02-04  Jeopardy!
# 126903  5268        2007-07-04  Jeopardy!
# 143302  6177        2011-06-21  Double Jeopardy!
# 151316  4289        2003-04-03  Jeopardy!
# 161756  4294        2003-04-10  Jeopardy!
# 181871  5940        2010-06-11  Jeopardy!
# 196710  4852        2005-10-18  Jeopardy!
# 199863  5812        2009-12-15  Double Jeopardy!
# 200288  3471        1999-10-11  Double Jeopardy!
#
#                              Category  Value  \
# 8563    SPORTS                         400
# 16055   OK COMPUTER                    400
# 17432   AIRLINE TRAVEL                 100
# 32512   THE SHORT FORM                 1600
# 36455   MOTHER NATURE'S STRANGE IDEAS  400
# 43698   TRINIDAD & TOBAGO              600
# 45878   TOOLS OF THE TRADE             4400
# 47130   FUN WITH ACRONYMS              500
# 71421   WORLD TRAVEL                   200
# 82397   THE ISLANDS OF VANUATU         1200
# 87030   FUN ACROSS AMERICA             400
# 88981   MORE REDUNDANCY & REPETITION   400
# 89715   OFFICIAL STATE STUFF           2000
# 122020  FIREFIGHTING                   5000
# 126257  HAZARDS                        800
# 126903  GIVE ME A SIGN                 400
# 143302  WHAT DO U STAND FOR?           800
# 151316  THE NATURAL WORLD              400
# 161756  WHAT A GAS!                    800
# 181871  COUSTEAU                       800
# 196710  LET'S GO CRUISING              200
# 199863  IT'S A GAS                     1200
# 200288  OF "LIFE"                      600
#
#                                                                                                                                                                                                                                                                                                                                                                                      Question  \
# 8563    What the letters in "scuba" stand for
# 16055   (<a href="http://www.j-archive.com/media/2006-05-15_J_26.wmv">Kelly of the Clue Crew accesses a video of Sarah of the Clue Crew scuba diving on the <i>Jeopardy!</i> web site from her laptop.</a>)  A synonym for "flowing", it's the type of video you can watch when you <a href="http://www.j-archive.com/media/2006-05-15_J_26.jpg" target="_blank">visit us</a> at jeopardy.com
# 17432   The Valsalva maneuver, also used by scuba divers, can "pop" these organs
# 32512   To a swimmer, SCUBA
# 36455   (Sarah of the Clue Crew scubadiving)  A stretched & twisted polyp forms the coral seen here, named for this human body part
# 43698   T&T are close enough to this country that the water from the Orinoco murks up scuba diving
# 45878   Tusa's visio, with a polycarbonate frame, is this piece of scuba equipment
# 47130   To a diver:  SCUBA
# 71421   Scuba divers love to explore the Marie Celeste, a blockade runner that sank off the coast of Bermuda during this war
# 82397   A WWII liner named for this "silent" president is one of the world's largest intact scuba-accessible shipwrecks
# 87030   If you're scuba-certified, you can swim with the sharks at the aquarium in this Minnesota shopping paradise
# 88981   This word, the "A" in the acronym scuba, makes "scuba gear" somewhat repetitive
# 89715   Go SCUBA diving in Hawaii & you may see the state gem, the black type of this
# 122020  Take the â€œUâ€ out of scuba to get this full name of firefighting gear used to go where oxygen is scarce
# 126257  The scuba diving hazard known as the bends results from this gas being released into the blood during a too rapid ascent
# 126903  This gesture can mean "cut power to the microphone" or, in scuba diving, "I'm out of air"
# 143302  In SCUBA
# 151316  (Sarah of the Clue Crew scuba diving in the Barrier Reef near Belize)  Sponges are classified based on what this structure is made of, such as calcium carbonate or silica
# 161756  When bubbles of this gas form in a scuba diver's blood, the bends can occur
# 181871  Cousteau co-designed <a href="http://www.j-archive.com/media/2010-06-11_J_29.wmv">this</a> scuba device & said it changed his life
# 196710  Princess Cruises now offer scuba & volleyball as well as this beloved game that uses cues to push disks
# 199863  Rising too fast from deep water forces nitrogen gas into the blood, causing this condition in scuba divers
# 200288  This type of "system" refers to space suits & scuba gear as well as medical devices like incubators
#
#                                                Answer
# 8563    self-contained underwater breathing apparatus
# 16055   streaming
# 17432   the ears
# 32512   self-contained underwater breathing apparatus
# 36455   brain
# 43698   Venezuela
# 45878   a mask
# 47130   Self Contained Underwater Breathing Apparatus
# 71421   the Civil War
# 82397   Coolidge
# 87030   the Mall of America
# 88981   apparatus
# 89715   coral
# 122020  a self-contained breathing apparatus
# 126257  nitrogen
# 126903  putting your hand across your (throat)
# 143302  underwater
# 151316  the skeleton
# 161756  nitrogen
# 181871  the aqua lung
# 196710  shuffleboard
# 199863  the bends
# 200288  Life support
